# %%
# !pip install transformers

# %%
import json
import logging

import numpy as np

import math


import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, Dataset
import torch.nn.functional as F
import torch.optim as optim

# import transformers
# from transformers import BartTokenizer, BartForConditionalGeneration

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score

# from matplotlib import pyplot

import time

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir("/content/drive/MyDrive/CS_NLP_BART")

# %%
class Random_atlas():

    def __init__(self, size=10000):
        self.size = size
        self.index = 0
        self.atlas = np.random.rand(self.size)

    def sample_atlas(self):
        if self.index >= self.size:
            self.index = 0
            self.atlas = np.random.rand(self.size)
        res = self.atlas[self.index]
        self.index += 1
        return res

    def int_in_range(self, range, blacklist):
        min, max = range
        dif = max - min

        # giving an error for to large black list.
        if len(blacklist) >= dif:
            # logging.error("The blacklist is covering the range can't get a random number")
            return 0, False # False is to indicate that the function can not return a random int

        # we sample a random integer in the given range
        random_num = self.sample_atlas()
        res = math.floor(random_num * dif) + min

        # we keep on re-sampling random integers until we get one not in the blacklist
        count = 0
        while res in blacklist:
            random_num = self.sample_atlas()
            res = math.floor(random_num * dif) + min
            count += 1
            if count >= 200:
                print("got stuck in while loop")
                return 0, False # False is to indicate that the function can not return a random int

        return res, True # True is to indicate that the function returned a random int

# %%
def generate_finetunning_data(events, number_of_samples, emb_type="CLS"):
    # Opening JSON file
    events = events

    # This give us the randomness
    random_atlas = Random_atlas(size=20000)

    # this will be the JSON we will save as the date.
    finetunning_data_0 = []
    finetunning_data_1 = []
    finetunning_lables = []
    debuging_lookup = []

    num_events = len(events)

    for (event_idx, event) in enumerate(events):
        print(f"event number {event_idx}")
        articles_list = event["articles"]

        num_articles = len(articles_list)

        # black list so that the same sample is not added twice
        inner_blacklist_dict = {i: [i] for i in range(num_articles)}

        for (article_idx, article) in enumerate(articles_list):

            # first we add same event samples
            for _ in range(number_of_samples):

                # get list of articles we should not sample from
                temp_blacklist = inner_blacklist_dict[article_idx]

                # get the random sample index, or learn that there are no random index to get
                other_article_index, found_random_int = random_atlas.int_in_range(range=(0, num_articles), blacklist=temp_blacklist)

                if found_random_int:

                    # update the blacklist
                    inner_blacklist_dict[article_idx].append(other_article_index)
                    inner_blacklist_dict[other_article_index].append(article_idx)

                    # add the new sample and its mirror
                    if emb_type=="CLS":
                        finetunning_data_0.append(article["CLS"])
                        finetunning_data_1.append(articles_list[other_article_index]["CLS"])
                        finetunning_lables.append(1)
                        debuging_lookup.append((event_idx, article_idx, event_idx, other_article_index, 1))

                        finetunning_data_0.append(articles_list[other_article_index]["CLS"])
                        finetunning_data_1.append(article["CLS"])
                        finetunning_lables.append(1)
                        debuging_lookup.append((event_idx, other_article_index, event_idx, article_idx, 1))
                    else:
                        logging.error(f"Only embedding types are 'CLS','AVG', and a different embedding type is given.")

            # second we add different event samples
            for _ in range(number_of_samples):
                # in this step we can not, fail to get a random int, so we ignore the true/false.

                # get the random sample event index, we must not sample from the same event so its is black listed
                other_event_index, _ = random_atlas.int_in_range(range=(0, num_events), blacklist=[event_idx])

                # get the random sample article index, we ignore the posibility of sampleing the same article here as is quite small
                other_event_num_articles = len(events[other_event_index]["articles"])
                other_article_index, _ = random_atlas.int_in_range(range=(0, other_event_num_articles), blacklist=[])

                # add the new sample and its mirror
                if emb_type == "CLS":
                    finetunning_data_0.append(article["CLS"])
                    finetunning_data_1.append(events[other_event_index]["articles"][other_article_index]["CLS"])

                    finetunning_lables.append(0)
                    debuging_lookup.append((event_idx, article_idx, other_event_index, other_article_index, 0))

                    finetunning_data_0.append(events[other_event_index]["articles"][other_article_index]["CLS"])
                    finetunning_data_1.append(article["CLS"])

                    finetunning_lables.append(0)
                    debuging_lookup.append((other_event_index, other_article_index, event_idx, article_idx, 0))

                else:
                    logging.error(f"Only embedding types are 'CLS','AVG', and a different embedding type is given.")

    return finetunning_data_0, finetunning_data_1, finetunning_lables, debuging_lookup
    print("debug")

# %%
class CustomFinetuningDataset(Dataset):
    def __init__(self, events, triplets):
        self.events = events
        self.triplets = triplets

    def __len__(self):
        return len(self.triplets)

    def __getitem__(self, idx):

        X_1_idx, X_2_idx, label = self.triplets[idx]

        X_1 = torch.FloatTensor(self.events[X_1_idx[0]]["articles"][X_1_idx[1]]["CLS"])
        X_2 = torch.FloatTensor(self.events[X_2_idx[0]]["articles"][X_2_idx[1]]["CLS"])
        label = torch.tensor(label, dtype=torch.int8).type(torch.long)

        return X_1, X_2, label

def generate_finetunning_dataset(events, number_of_samples, emb_type="CLS"):
    # Opening JSON file
    events = events

    # This give us the randomness
    random_atlas = Random_atlas(size=20000)

    # this will be the JSON we will save as the date.
    triplets = []

    num_events = len(events)

    for (event_idx, event) in enumerate(events):
        print(f"event number {event_idx}")
        articles_list = event["articles"]

        num_articles = len(articles_list)

        # black list so that the same sample is not added twice
        inner_blacklist_dict = {i: [i] for i in range(num_articles)}

        for (article_idx, article) in enumerate(articles_list):

            # first we add same event samples
            for _ in range(number_of_samples):

                # get list of articles we should not sample from
                temp_blacklist = inner_blacklist_dict[article_idx]

                # get the random sample index, or learn that there are no random index to get
                other_article_index, found_random_int = random_atlas.int_in_range(range=(0, num_articles), blacklist=temp_blacklist)

                if found_random_int:

                    # update the blacklist
                    inner_blacklist_dict[article_idx].append(other_article_index)
                    inner_blacklist_dict[other_article_index].append(article_idx)

                    # add the new sample and its mirror
                    if emb_type=="CLS":
                        triplets.append(((event_idx, article_idx), (event_idx, other_article_index), 1))
                        triplets.append(((event_idx, other_article_index), (event_idx, article_idx), 1))
                    else:
                        logging.error(f"Only embedding types are 'CLS','AVG', and a different embedding type is given.")

            # second we add different event samples
            for _ in range(number_of_samples):
                # in this step we can not, fail to get a random int, so we ignore the true/false.

                # get the random sample event index, we must not sample from the same event so its is black listed
                other_event_index, _ = random_atlas.int_in_range(range=(0, num_events), blacklist=[event_idx])

                # get the random sample article index, we ignore the posibility of sampleing the same article here as is quite small
                other_event_num_articles = len(events[other_event_index]["articles"])
                other_article_index, _ = random_atlas.int_in_range(range=(0, other_event_num_articles), blacklist=[])

                # add the new sample and its mirror
                if emb_type == "CLS":
                    triplets.append(((event_idx, article_idx), (other_event_index, other_article_index), 0))
                    triplets.append(((other_event_index, other_article_index), (event_idx, article_idx), 0))

                else:
                    logging.error(f"Only embedding types are 'CLS','AVG', and a different embedding type is given.")

    finetunning_dataset = CustomFinetuningDataset(events, triplets)

    return finetunning_dataset

# %%
class Encoder(nn.Module):
    def __init__(self):
        """
        The constructor of the model.
        """
        super().__init__()
        # and then used to extract features from the training and test data.

        # 1024 ==> 1024
        self.encoder = torch.nn.Sequential(
            torch.nn.Linear(1024, 2048),
            torch.nn.ReLU()
        )

    def forward(self, x):
        """
        The forward pass of the model.

        input: x: torch.Tensor, the input to the model

        output: x: torch.Tensor, the output of the model
        """
        # defined in the constructor.
        encoded = self.encoder(x)

        return encoded


class Net(nn.Module):
    def __init__(self, encoder):
        """
        The constructor of the model.
        """
        super().__init__()
        # and then used to extract features from the training and test data.

        # 1024 ==> 1024
        # self.encoder_1 = encoder
        # self.encoder_2 = Encoder()
        self.encoder = encoder

        # 2048 ==> 1
        self.fc = torch.nn.Sequential(
            torch.nn.Linear(4096, 2048),
            torch.nn.ReLU(),
            torch.nn.Linear(2048, 1024),
            torch.nn.ReLU(),
            torch.nn.Linear(1024, 1)
        )

    def forward(self, x_1, x_2):
        """
        The forward pass of the model.

        input: x: torch.Tensor, the input to the model

        output: x: torch.Tensor, the output of the model
        """
        # defined in the constructor.
        encoded_1 = self.encoder(x_1)
        encoded_2 = self.encoder(x_2)
        encoded = torch.cat((encoded_1, encoded_2), 1)
        res = self.fc(encoded)
        res = F.sigmoid(res)
        return res

# %%
def create_loader_from_np(X_1, X_2, y=None, train=True, batch_size=32, shuffle=True, num_workers=0):
    """
    Create a torch.utils.data.DataLoader object from numpy arrays containing the data.

    input: X: numpy array, the features
           y: numpy array, the labels

    output: loader: torch.data.util.DataLoader, the object containing the data
    """
    if train:
        dataset = TensorDataset(torch.from_numpy(X_1).type(torch.float),
                                torch.from_numpy(X_2).type(torch.float),
                                torch.from_numpy(y).type(torch.long))
        loader = DataLoader(dataset=dataset,
                              batch_size=batch_size,
                              shuffle=shuffle,
                              pin_memory=True, num_workers=num_workers)

    else:
        dataset = TensorDataset(torch.from_numpy(X_1).type(torch.float),
                                torch.from_numpy(X_2).type(torch.float))
        loader = DataLoader(dataset=dataset,
                              batch_size=batch_size,
                              shuffle=shuffle,
                              pin_memory=True, num_workers=num_workers)
    return loader

# %%
def create_loader_from_list(X_1, X_2, y=None, train=True, batch_size=32, shuffle=True, num_workers=0):
    """
    Create a torch.utils.data.DataLoader object from numpy arrays containing the data.

    input: X: numpy array, the features
           y: numpy array, the labels

    output: loader: torch.data.util.DataLoader, the object containing the data
    """
    if train:
        dataset = TensorDataset(torch.Tensor(X_1).type(torch.float),
                                torch.Tensor(X_2).type(torch.float),
                                torch.Tensor(y).type(torch.long))
        loader = DataLoader(dataset=dataset,
                              batch_size=batch_size,
                              shuffle=shuffle,
                              pin_memory=True, num_workers=num_workers)

    else:
        dataset = TensorDataset(torch.Tensor(X_1).type(torch.float),
                                torch.Tensor(X_2).type(torch.float))
        loader = DataLoader(dataset=dataset,
                              batch_size=batch_size,
                              shuffle=shuffle,
                              pin_memory=True, num_workers=num_workers)
    return loader

# %%
def finetune_model(encoder, net, train_loader, val_loader):

    train_loader = train_loader
    val_loader = val_loader

    encoder = encoder
    model = net

    model.to(device)

    n_epochs = 100


    criterion = nn.BCELoss()

    print("new 2")

    # create your optimizer
    optimizer = optim.AdamW(model.parameters(), lr=0.0002, weight_decay=0.1)
    val_losses = []
    train_losses = []

    best_val_loss = 0.2

    for epoch in range(n_epochs):
        model.train()
        loss_to_print = 0.0
        e_loss = 0.0
        predictions = []
        y_true = []
        for i, [X_1, X_2, y] in enumerate(train_loader):
            X_1 = X_1.to(device)
            X_2 = X_2.to(device)
            y = y.to(device)

            optimizer.zero_grad()

            preds = model(X_1, X_2)
            loss = criterion(torch.reshape(preds, (-1,)), y.to(torch.float32))
            loss.backward()
            optimizer.step()
            e_loss += loss.item()
            loss_to_print += loss.item()
            if i % 1000 == 999:
                print(f"[{epoch + 1}, {i + 1:5d}], loss: {loss_to_print / 1000:.3f}")
                loss_to_print = 0.0
        print(f"[Epoch {epoch + 1:2d}] Epoch Loss: {e_loss / len(train_loader):.5f}", end=" | ")
        train_losses.append(e_loss / len(train_loader))
        model.eval()
        val_loss_p = 0

        with torch.no_grad():  # We don't need to compute gradients for testing
            for [x_val_1, x_val_2, y_val] in val_loader:
                x_val_1 = x_val_1.to(device)
                x_val_2 = x_val_2.to(device)
                y_val = y_val.to(device)
                y_hat = model(x_val_1, x_val_2)
                val_loss = criterion(torch.reshape(y_hat, (-1,)), y_val.to(torch.float32))
                val_loss_p += val_loss.item()
                predicted = y_hat.cpu().numpy()
                y_batch = y_val.cpu().numpy()

                # Rounding the predictions to 0 or 1
                predicted[predicted >= 0.5] = 1
                predicted[predicted < 0.5] = 0
                predictions.append(predicted)
                y_true.extend(y_batch)




        predictions = np.vstack(predictions)
        val_loss_p = val_loss_p / len(val_loader)
        acc = accuracy_score(y_true, predictions)
        print(f"Val Loss: {val_loss_p:.5f}, Val Accuracy: {acc:.5f}")
        val_losses.append(val_loss_p)

        if val_loss_p < best_val_loss:
            print(f"New Best Loss: {val_loss_p:.5f}")
            best_val_loss = val_loss_p
            torch.save(encoder, f"./encoder.pt")
            torch.save(model, f"./model.pt")

    # torch.save(encoder, f"./encoder.pt")
    # torch.save(model, f"./model.pt")

    return train_losses, val_losses

# %%
f = open('data_5000_with_BART_embedings_CLS.json')
events = json.load(f)

# %%
# events_train = events[:4500]
# events_val = events[4500:]


# finetunning_data_train_X_0, finetunning_data_train_X_1, finetunning_data_train_y, debuging_lookup_tr = generate_finetunning_data(events[:4500], number_of_samples=5, emb_type="CLS")
# finetunning_data_val_X_0, finetunning_data_val_X_1, finetunning_data_val_y, debuging_lookup_val = generate_finetunning_data(events[4500:], number_of_samples=5, emb_type="CLS")

# %%
# train_loader = create_loader_from_list(finetunning_data_train_X_0, finetunning_data_train_X_1, finetunning_data_train_y, batch_size=512, shuffle=True)
# val_loader = create_loader_from_list(finetunning_data_val_X_0, finetunning_data_val_X_1, finetunning_data_val_y, batch_size=512, shuffle=False)

# %%
events_train = events[:4500]
events_val = events[4500:]

train_loader = DataLoader(dataset= generate_finetunning_dataset(events_train, number_of_samples=10, emb_type="CLS"),
                          batch_size=512,
                          shuffle=True,
                          pin_memory=True,
                          num_workers=4)
val_loader = DataLoader(dataset= generate_finetunning_dataset(events_val, number_of_samples=10, emb_type="CLS"),
                          batch_size=512,
                          shuffle=False,
                          pin_memory=True,
                          num_workers=4)
# Out:
# event number 0
# event number 1
# event number 2
# event number 3
# event number 4
# event number 5
# event number 6
# event number 7
# event number 8
# event number 9
# event number 10
# event number 11
# event number 12
# event number 13
# event number 14
# event number 15
# event number 16
# event number 17
# event number 18
# event number 19
# event number 20
# event number 21
# event number 22
# event number 23
# event number 24
# event number 25
# event number 26
# event number 27
# event number 28
# event number 29
# event number 30
# event number 31
# event number 32
# event number 33
# event number 34
# event number 35
# event number 36
# event number 37
# event number 38
# event number 39
# event number 40
# event number 41
# event number 42
# event number 43
# event number 44
# event number 45
# event number 46
# event number 47
# event number 48
# event number 49
# event number 50
# event number 51
# event number 52
# event number 53
# event number 54
# event number 55
# event number 56
# event number 57
# event number 58
# event number 59
# event number 60
# event number 61
# event number 62
# event number 63
# event number 64
# event number 65
# event number 66
# event number 67
# event number 68
# event number 69
# event number 70
# event number 71
# event number 72
# event number 73
# event number 74
# event number 75
# event number 76
# event number 77
# event number 78
# event number 79
# event number 80
# event number 81
# event number 82
# event number 83
# event number 84
# event number 85
# event number 86
# event number 87
# event number 88
# event number 89
# event number 90
# event number 91
# event number 92
# event number 93
# event number 94
# event number 95
# event number 96
# event number 97
# event number 98
# event number 99
# event number 100
# event number 101
# event number 102
# event number 103
# event number 104
# event number 105
# event number 106
# event number 107
# event number 108
# event number 109
# event number 110
# event number 111
# event number 112
# event number 113
# event number 114
# event number 115
# event number 116
# event number 117
# event number 118
# event number 119
# event number 120
# event number 121
# event number 122
# event number 123
# event number 124
# event number 125
# event number 126
# event number 127
# event number 128
# event number 129
# event number 130
# event number 131
# event number 132
# event number 133
# event number 134
# event number 135
# event number 136
# event number 137
# event number 138
# event number 139
# event number 140
# event number 141
# event number 142
# event number 143
# event number 144
# event number 145
# event number 146
# event number 147
# event number 148
# event number 149
# event number 150
# event number 151
# event number 152
# event number 153
# event number 154
# event number 155
# event number 156
# event number 157
# event number 158
# event number 159
# event number 160
# event number 161
# event number 162
# event number 163
# event number 164
# event number 165
# event number 166
# event number 167
# event number 168
# event number 169
# event number 170
# event number 171
# event number 172
# event number 173
# event number 174
# event number 175
# event number 176
# event number 177
# event number 178
# event number 179
# event number 180
# event number 181
# event number 182
# event number 183
# event number 184
# event number 185
# event number 186
# event number 187
# event number 188
# event number 189
# event number 190
# event number 191
# event number 192
# event number 193
# event number 194
# event number 195
# event number 196
# event number 197
# event number 198
# event number 199
# event number 200
# event number 201
# event number 202
# event number 203
# event number 204
# event number 205
# event number 206
# event number 207
# event number 208
# event number 209
# event number 210
# event number 211
# event number 212
# event number 213
# event number 214
# event number 215
# event number 216
# event number 217
# event number 218
# event number 219
# event number 220
# event number 221
# event number 222
# event number 223
# event number 224
# event number 225
# event number 226
# event number 227
# event number 228
# event number 229
# event number 230
# event number 231
# event number 232
# event number 233
# event number 234
# event number 235
# event number 236
# event number 237
# event number 238
# event number 239
# event number 240
# event number 241
# event number 242
# event number 243
# event number 244
# event number 245
# event number 246
# event number 247
# event number 248
# event number 249
# event number 250
# event number 251
# event number 252
# event number 253
# event number 254
# event number 255
# event number 256
# event number 257
# event number 258
# event number 259
# event number 260
# event number 261
# event number 262
# event number 263
# event number 264
# event number 265
# event number 266
# event number 267
# event number 268
# event number 269
# event number 270
# event number 271
# event number 272
# event number 273
# event number 274
# event number 275
# event number 276
# event number 277
# event number 278
# event number 279
# event number 280
# event number 281
# event number 282
# event number 283
# event number 284
# event number 285
# event number 286
# event number 287
# event number 288
# event number 289
# event number 290
# event number 291
# event number 292
# event number 293
# event number 294
# event number 295
# event number 296
# event number 297
# event number 298
# event number 299
# event number 300
# event number 301
# event number 302
# event number 303
# event number 304
# event number 305
# event number 306
# event number 307
# event number 308
# event number 309
# event number 310
# event number 311
# event number 312
# event number 313
# event number 314
# event number 315
# event number 316
# event number 317
# event number 318
# event number 319
# event number 320
# event number 321
# event number 322
# event number 323
# event number 324
# event number 325
# event number 326
# event number 327
# event number 328
# event number 329
# event number 330
# event number 331
# event number 332
# event number 333
# event number 334
# event number 335
# event number 336
# event number 337
# event number 338
# event number 339
# event number 340
# event number 341
# event number 342
# event number 343
# event number 344
# event number 345
# event number 346
# event number 347
# event number 348
# event number 349
# event number 350
# event number 351
# event number 352
# event number 353
# event number 354
# event number 355
# event number 356
# event number 357
# event number 358
# event number 359
# event number 360
# event number 361
# event number 362
# event number 363
# event number 364
# event number 365
# event number 366
# event number 367
# event number 368
# event number 369
# event number 370
# event number 371
# event number 372
# event number 373
# event number 374
# event number 375
# event number 376
# event number 377
# event number 378
# event number 379
# event number 380
# event number 381
# event number 382
# event number 383
# event number 384
# event number 385
# event number 386
# event number 387
# event number 388
# event number 389
# event number 390
# event number 391
# event number 392
# event number 393
# event number 394
# event number 395
# event number 396
# event number 397
# event number 398
# event number 399
# event number 400
# event number 401
# event number 402
# event number 403
# event number 404
# event number 405
# event number 406
# event number 407
# event number 408
# event number 409
# event number 410
# event number 411
# event number 412
# event number 413
# event number 414
# event number 415
# event number 416
# event number 417
# event number 418
# event number 419
# event number 420
# event number 421
# event number 422
# event number 423
# event number 424
# event number 425
# event number 426
# event number 427
# event number 428
# event number 429
# event number 430
# event number 431
# event number 432
# event number 433
# event number 434
# event number 435
# event number 436
# event number 437
# event number 438
# event number 439
# event number 440
# event number 441
# event number 442
# event number 443
# event number 444
# event number 445
# event number 446
# event number 447
# event number 448
# event number 449
# event number 450
# event number 451
# event number 452
# event number 453
# event number 454
# event number 455
# event number 456
# event number 457
# event number 458
# event number 459
# event number 460
# event number 461
# event number 462
# event number 463
# event number 464
# event number 465
# event number 466
# event number 467
# event number 468
# event number 469
# event number 470
# event number 471
# event number 472
# event number 473
# event number 474
# event number 475
# event number 476
# event number 477
# event number 478
# event number 479
# event number 480
# event number 481
# event number 482
# event number 483
# event number 484
# event number 485
# event number 486
# event number 487
# event number 488
# event number 489
# event number 490
# event number 491
# event number 492
# event number 493
# event number 494
# event number 495
# event number 496
# event number 497
# event number 498
# event number 499
# event number 500
# event number 501
# event number 502
# event number 503
# event number 504
# event number 505
# event number 506
# event number 507
# event number 508
# event number 509
# event number 510
# event number 511
# event number 512
# event number 513
# event number 514
# event number 515
# event number 516
# event number 517
# event number 518
# event number 519
# event number 520
# event number 521
# event number 522
# event number 523
# event number 524
# event number 525
# event number 526
# event number 527
# event number 528
# event number 529
# event number 530
# event number 531
# event number 532
# event number 533
# event number 534
# event number 535
# event number 536
# event number 537
# event number 538
# event number 539
# event number 540
# event number 541
# event number 542
# event number 543
# event number 544
# event number 545
# event number 546
# event number 547
# event number 548
# event number 549
# event number 550
# event number 551
# event number 552
# event number 553
# event number 554
# event number 555
# event number 556
# event number 557
# event number 558
# event number 559
# event number 560
# event number 561
# event number 562
# event number 563
# event number 564
# event number 565
# event number 566
# event number 567
# event number 568
# event number 569
# event number 570
# event number 571
# event number 572
# event number 573
# event number 574
# event number 575
# event number 576
# event number 577
# event number 578
# event number 579
# event number 580
# event number 581
# event number 582
# event number 583
# event number 584
# event number 585
# event number 586
# event number 587
# event number 588
# event number 589
# event number 590
# event number 591
# event number 592
# event number 593
# event number 594
# event number 595
# event number 596
# event number 597
# event number 598
# event number 599
# event number 600
# event number 601
# event number 602
# event number 603
# event number 604
# event number 605
# event number 606
# event number 607
# event number 608
# event number 609
# event number 610
# event number 611
# event number 612
# event number 613
# event number 614
# event number 615
# event number 616
# event number 617
# event number 618
# event number 619
# event number 620
# event number 621
# event number 622
# event number 623
# event number 624
# event number 625
# event number 626
# event number 627
# event number 628
# event number 629
# event number 630
# event number 631
# event number 632
# event number 633
# event number 634
# event number 635
# event number 636
# event number 637
# event number 638
# event number 639
# event number 640
# event number 641
# event number 642
# event number 643
# event number 644
# event number 645
# event number 646
# event number 647
# event number 648
# event number 649
# event number 650
# event number 651
# event number 652
# event number 653
# event number 654
# event number 655
# event number 656
# event number 657
# event number 658
# event number 659
# event number 660
# event number 661
# event number 662
# event number 663
# event number 664
# event number 665
# event number 666
# event number 667
# event number 668
# event number 669
# event number 670
# event number 671
# event number 672
# event number 673
# event number 674
# event number 675
# event number 676
# event number 677
# event number 678
# event number 679
# event number 680
# event number 681
# event number 682
# event number 683
# event number 684
# event number 685
# event number 686
# event number 687
# event number 688
# event number 689
# event number 690
# event number 691
# event number 692
# event number 693
# event number 694
# event number 695
# event number 696
# event number 697
# event number 698
# event number 699
# event number 700
# event number 701
# event number 702
# event number 703
# event number 704
# event number 705
# event number 706
# event number 707
# event number 708
# event number 709
# event number 710
# event number 711
# event number 712
# event number 713
# event number 714
# event number 715
# event number 716
# event number 717
# event number 718
# event number 719
# event number 720
# event number 721
# event number 722
# event number 723
# event number 724
# event number 725
# event number 726
# event number 727
# event number 728
# event number 729
# event number 730
# event number 731
# event number 732
# event number 733
# event number 734
# event number 735
# event number 736
# event number 737
# event number 738
# event number 739
# event number 740
# event number 741
# event number 742
# event number 743
# event number 744
# event number 745
# event number 746
# event number 747
# event number 748
# event number 749
# event number 750
# event number 751
# event number 752
# event number 753
# event number 754
# event number 755
# event number 756
# event number 757
# event number 758
# event number 759
# event number 760
# event number 761
# event number 762
# event number 763
# event number 764
# event number 765
# event number 766
# event number 767
# event number 768
# event number 769
# event number 770
# event number 771
# event number 772
# event number 773
# event number 774
# event number 775
# event number 776
# event number 777
# event number 778
# event number 779
# event number 780
# event number 781
# event number 782
# event number 783
# event number 784
# event number 785
# event number 786
# event number 787
# event number 788
# event number 789
# event number 790
# event number 791
# event number 792
# event number 793
# event number 794
# event number 795
# event number 796
# event number 797
# event number 798
# event number 799
# event number 800
# event number 801
# event number 802
# event number 803
# event number 804
# event number 805
# event number 806
# event number 807
# event number 808
# event number 809
# event number 810
# event number 811
# event number 812
# event number 813
# event number 814
# event number 815
# event number 816
# event number 817
# event number 818
# event number 819
# event number 820
# event number 821
# event number 822
# event number 823
# event number 824
# event number 825
# event number 826
# event number 827
# event number 828
# event number 829
# event number 830
# event number 831
# event number 832
# event number 833
# event number 834
# event number 835
# event number 836
# event number 837
# event number 838
# event number 839
# event number 840
# event number 841
# event number 842
# event number 843
# event number 844
# event number 845
# event number 846
# event number 847
# event number 848
# event number 849
# event number 850
# event number 851
# event number 852
# event number 853
# event number 854
# event number 855
# event number 856
# event number 857
# event number 858
# event number 859
# event number 860
# event number 861
# event number 862
# event number 863
# event number 864
# event number 865
# event number 866
# event number 867
# event number 868
# event number 869
# event number 870
# event number 871
# event number 872
# event number 873
# event number 874
# event number 875
# event number 876
# event number 877
# event number 878
# event number 879
# event number 880
# event number 881
# event number 882
# event number 883
# event number 884
# event number 885
# event number 886
# event number 887
# event number 888
# event number 889
# event number 890
# event number 891
# event number 892
# event number 893
# event number 894
# event number 895
# event number 896
# event number 897
# event number 898
# event number 899
# event number 900
# event number 901
# event number 902
# event number 903
# event number 904
# event number 905
# event number 906
# event number 907
# event number 908
# event number 909
# event number 910
# event number 911
# event number 912
# event number 913
# event number 914
# event number 915
# event number 916
# event number 917
# event number 918
# event number 919
# event number 920
# event number 921
# event number 922
# event number 923
# event number 924
# event number 925
# event number 926
# event number 927
# event number 928
# event number 929
# event number 930
# event number 931
# event number 932
# event number 933
# event number 934
# event number 935
# event number 936
# event number 937
# event number 938
# event number 939
# event number 940
# event number 941
# event number 942
# event number 943
# event number 944
# event number 945
# event number 946
# event number 947
# event number 948
# event number 949
# event number 950
# event number 951
# event number 952
# event number 953
# event number 954
# event number 955
# event number 956
# event number 957
# event number 958
# event number 959
# event number 960
# event number 961
# event number 962
# event number 963
# event number 964
# event number 965
# event number 966
# event number 967
# event number 968
# event number 969
# event number 970
# event number 971
# event number 972
# event number 973
# event number 974
# event number 975
# event number 976
# event number 977
# event number 978
# event number 979
# event number 980
# event number 981
# event number 982
# event number 983
# event number 984
# event number 985
# event number 986
# event number 987
# event number 988
# event number 989
# event number 990
# event number 991
# event number 992
# event number 993
# event number 994
# event number 995
# event number 996
# event number 997
# event number 998
# event number 999
# event number 1000
# event number 1001
# event number 1002
# event number 1003
# event number 1004
# event number 1005
# event number 1006
# event number 1007
# event number 1008
# event number 1009
# event number 1010
# event number 1011
# event number 1012
# event number 1013
# event number 1014
# event number 1015
# event number 1016
# event number 1017
# event number 1018
# event number 1019
# event number 1020
# event number 1021
# event number 1022
# event number 1023
# event number 1024
# event number 1025
# event number 1026
# event number 1027
# event number 1028
# event number 1029
# event number 1030
# event number 1031
# event number 1032
# event number 1033
# event number 1034
# event number 1035
# event number 1036
# event number 1037
# event number 1038
# event number 1039
# event number 1040
# event number 1041
# event number 1042
# event number 1043
# event number 1044
# event number 1045
# event number 1046
# event number 1047
# event number 1048
# event number 1049
# event number 1050
# event number 1051
# event number 1052
# event number 1053
# event number 1054
# event number 1055
# event number 1056
# event number 1057
# event number 1058
# event number 1059
# event number 1060
# event number 1061
# event number 1062
# event number 1063
# event number 1064
# event number 1065
# event number 1066
# event number 1067
# event number 1068
# event number 1069
# event number 1070
# event number 1071
# event number 1072
# event number 1073
# event number 1074
# event number 1075
# event number 1076
# event number 1077
# event number 1078
# event number 1079
# event number 1080
# event number 1081
# event number 1082
# event number 1083
# event number 1084
# event number 1085
# event number 1086
# event number 1087
# event number 1088
# event number 1089
# event number 1090
# event number 1091
# event number 1092
# event number 1093
# event number 1094
# event number 1095
# event number 1096
# event number 1097
# event number 1098
# event number 1099
# event number 1100
# event number 1101
# event number 1102
# event number 1103
# event number 1104
# event number 1105
# event number 1106
# event number 1107
# event number 1108
# event number 1109
# event number 1110
# event number 1111
# event number 1112
# event number 1113
# event number 1114
# event number 1115
# event number 1116
# event number 1117
# event number 1118
# event number 1119
# event number 1120
# event number 1121
# event number 1122
# event number 1123
# event number 1124
# event number 1125
# event number 1126
# event number 1127
# event number 1128
# event number 1129
# event number 1130
# event number 1131
# event number 1132
# event number 1133
# event number 1134
# event number 1135
# event number 1136
# event number 1137
# event number 1138
# event number 1139
# event number 1140
# event number 1141
# event number 1142
# event number 1143
# event number 1144
# event number 1145
# event number 1146
# event number 1147
# event number 1148
# event number 1149
# event number 1150
# event number 1151
# event number 1152
# event number 1153
# event number 1154
# event number 1155
# event number 1156
# event number 1157
# event number 1158
# event number 1159
# event number 1160
# event number 1161
# event number 1162
# event number 1163
# event number 1164
# event number 1165
# event number 1166
# event number 1167
# event number 1168
# event number 1169
# event number 1170
# event number 1171
# event number 1172
# event number 1173
# event number 1174
# event number 1175
# event number 1176
# event number 1177
# event number 1178
# event number 1179
# event number 1180
# event number 1181
# event number 1182
# event number 1183
# event number 1184
# event number 1185
# event number 1186
# event number 1187
# event number 1188
# event number 1189
# event number 1190
# event number 1191
# event number 1192
# event number 1193
# event number 1194
# event number 1195
# event number 1196
# event number 1197
# event number 1198
# event number 1199
# event number 1200
# event number 1201
# event number 1202
# event number 1203
# event number 1204
# event number 1205
# event number 1206
# event number 1207
# event number 1208
# event number 1209
# event number 1210
# event number 1211
# event number 1212
# event number 1213
# event number 1214
# event number 1215
# event number 1216
# event number 1217
# event number 1218
# event number 1219
# event number 1220
# event number 1221
# event number 1222
# event number 1223
# event number 1224
# event number 1225
# event number 1226
# event number 1227
# event number 1228
# event number 1229
# event number 1230
# event number 1231
# event number 1232
# event number 1233
# event number 1234
# event number 1235
# event number 1236
# event number 1237
# event number 1238
# event number 1239
# event number 1240
# event number 1241
# event number 1242
# event number 1243
# event number 1244
# event number 1245
# event number 1246
# event number 1247
# event number 1248
# event number 1249
# event number 1250
# event number 1251
# event number 1252
# event number 1253
# event number 1254
# event number 1255
# event number 1256
# event number 1257
# event number 1258
# event number 1259
# event number 1260
# event number 1261
# event number 1262
# event number 1263
# event number 1264
# event number 1265
# event number 1266
# event number 1267
# event number 1268
# event number 1269
# event number 1270
# event number 1271
# event number 1272
# event number 1273
# event number 1274
# event number 1275
# event number 1276
# event number 1277
# event number 1278
# event number 1279
# event number 1280
# event number 1281
# event number 1282
# event number 1283
# event number 1284
# event number 1285
# event number 1286
# event number 1287
# event number 1288
# event number 1289
# event number 1290
# event number 1291
# event number 1292
# event number 1293
# event number 1294
# event number 1295
# event number 1296
# event number 1297
# event number 1298
# event number 1299
# event number 1300
# event number 1301
# event number 1302
# event number 1303
# event number 1304
# event number 1305
# event number 1306
# event number 1307
# event number 1308
# event number 1309
# event number 1310
# event number 1311
# event number 1312
# event number 1313
# event number 1314
# event number 1315
# event number 1316
# event number 1317
# event number 1318
# event number 1319
# event number 1320
# event number 1321
# event number 1322
# event number 1323
# event number 1324
# event number 1325
# event number 1326
# event number 1327
# event number 1328
# event number 1329
# event number 1330
# event number 1331
# event number 1332
# event number 1333
# event number 1334
# event number 1335
# event number 1336
# event number 1337
# event number 1338
# event number 1339
# event number 1340
# event number 1341
# event number 1342
# event number 1343
# event number 1344
# event number 1345
# event number 1346
# event number 1347
# event number 1348
# event number 1349
# event number 1350
# event number 1351
# event number 1352
# event number 1353
# event number 1354
# event number 1355
# event number 1356
# event number 1357
# event number 1358
# event number 1359
# event number 1360
# event number 1361
# event number 1362
# event number 1363
# event number 1364
# event number 1365
# event number 1366
# event number 1367
# event number 1368
# event number 1369
# event number 1370
# event number 1371
# event number 1372
# event number 1373
# event number 1374
# event number 1375
# event number 1376
# event number 1377
# event number 1378
# event number 1379
# event number 1380
# event number 1381
# event number 1382
# event number 1383
# event number 1384
# event number 1385
# event number 1386
# event number 1387
# event number 1388
# event number 1389
# event number 1390
# event number 1391
# event number 1392
# event number 1393
# event number 1394
# event number 1395
# event number 1396
# event number 1397
# event number 1398
# event number 1399
# event number 1400
# event number 1401
# event number 1402
# event number 1403
# event number 1404
# event number 1405
# event number 1406
# event number 1407
# event number 1408
# event number 1409
# event number 1410
# event number 1411
# event number 1412
# event number 1413
# event number 1414
# event number 1415
# event number 1416
# event number 1417
# event number 1418
# event number 1419
# event number 1420
# event number 1421
# event number 1422
# event number 1423
# event number 1424
# event number 1425
# event number 1426
# event number 1427
# event number 1428
# event number 1429
# event number 1430
# event number 1431
# event number 1432
# event number 1433
# event number 1434
# event number 1435
# event number 1436
# event number 1437
# event number 1438
# event number 1439
# event number 1440
# event number 1441
# event number 1442
# event number 1443
# event number 1444
# event number 1445
# event number 1446
# event number 1447
# event number 1448
# event number 1449
# event number 1450
# event number 1451
# event number 1452
# event number 1453
# event number 1454
# event number 1455
# event number 1456
# event number 1457
# event number 1458
# event number 1459
# event number 1460
# event number 1461
# event number 1462
# event number 1463
# event number 1464
# event number 1465
# event number 1466
# event number 1467
# event number 1468
# event number 1469
# event number 1470
# event number 1471
# event number 1472
# event number 1473
# event number 1474
# event number 1475
# event number 1476
# event number 1477
# event number 1478
# event number 1479
# event number 1480
# event number 1481
# event number 1482
# event number 1483
# event number 1484
# event number 1485
# event number 1486
# event number 1487
# event number 1488
# event number 1489
# event number 1490
# event number 1491
# event number 1492
# event number 1493
# event number 1494
# event number 1495
# event number 1496
# event number 1497
# event number 1498
# event number 1499
# event number 1500
# event number 1501
# event number 1502
# event number 1503
# event number 1504
# event number 1505
# event number 1506
# event number 1507
# event number 1508
# event number 1509
# event number 1510
# event number 1511
# event number 1512
# event number 1513
# event number 1514
# event number 1515
# event number 1516
# event number 1517
# event number 1518
# event number 1519
# event number 1520
# event number 1521
# event number 1522
# event number 1523
# event number 1524
# event number 1525
# event number 1526
# event number 1527
# event number 1528
# event number 1529
# event number 1530
# event number 1531
# event number 1532
# event number 1533
# event number 1534
# event number 1535
# event number 1536
# event number 1537
# event number 1538
# event number 1539
# event number 1540
# event number 1541
# event number 1542
# event number 1543
# event number 1544
# event number 1545
# event number 1546
# event number 1547
# event number 1548
# event number 1549
# event number 1550
# event number 1551
# event number 1552
# event number 1553
# event number 1554
# event number 1555
# event number 1556
# event number 1557
# event number 1558
# event number 1559
# event number 1560
# event number 1561
# event number 1562
# event number 1563
# event number 1564
# event number 1565
# event number 1566
# event number 1567
# event number 1568
# event number 1569
# event number 1570
# event number 1571
# event number 1572
# event number 1573
# event number 1574
# event number 1575
# event number 1576
# event number 1577
# event number 1578
# event number 1579
# event number 1580
# event number 1581
# event number 1582
# event number 1583
# event number 1584
# event number 1585
# event number 1586
# event number 1587
# event number 1588
# event number 1589
# event number 1590
# event number 1591
# event number 1592
# event number 1593
# event number 1594
# event number 1595
# event number 1596
# event number 1597
# event number 1598
# event number 1599
# event number 1600
# event number 1601
# event number 1602
# event number 1603
# event number 1604
# event number 1605
# event number 1606
# event number 1607
# event number 1608
# event number 1609
# event number 1610
# event number 1611
# event number 1612
# event number 1613
# event number 1614
# event number 1615
# event number 1616
# event number 1617
# event number 1618
# event number 1619
# event number 1620
# event number 1621
# event number 1622
# event number 1623
# event number 1624
# event number 1625
# event number 1626
# event number 1627
# event number 1628
# event number 1629
# event number 1630
# event number 1631
# event number 1632
# event number 1633
# event number 1634
# event number 1635
# event number 1636
# event number 1637
# event number 1638
# event number 1639
# event number 1640
# event number 1641
# event number 1642
# event number 1643
# event number 1644
# event number 1645
# event number 1646
# event number 1647
# event number 1648
# event number 1649
# event number 1650
# event number 1651
# event number 1652
# event number 1653
# event number 1654
# event number 1655
# event number 1656
# event number 1657
# event number 1658
# event number 1659
# event number 1660
# event number 1661
# event number 1662
# event number 1663
# event number 1664
# event number 1665
# event number 1666
# event number 1667
# event number 1668
# event number 1669
# event number 1670
# event number 1671
# event number 1672
# event number 1673
# event number 1674
# event number 1675
# event number 1676
# event number 1677
# event number 1678
# event number 1679
# event number 1680
# event number 1681
# event number 1682
# event number 1683
# event number 1684
# event number 1685
# event number 1686
# event number 1687
# event number 1688
# event number 1689
# event number 1690
# event number 1691
# event number 1692
# event number 1693
# event number 1694
# event number 1695
# event number 1696
# event number 1697
# event number 1698
# event number 1699
# event number 1700
# event number 1701
# event number 1702
# event number 1703
# event number 1704
# event number 1705
# event number 1706
# event number 1707
# event number 1708
# event number 1709
# event number 1710
# event number 1711
# event number 1712
# event number 1713
# event number 1714
# event number 1715
# event number 1716
# event number 1717
# event number 1718
# event number 1719
# event number 1720
# event number 1721
# event number 1722
# event number 1723
# event number 1724
# event number 1725
# event number 1726
# event number 1727
# event number 1728
# event number 1729
# event number 1730
# event number 1731
# event number 1732
# event number 1733
# event number 1734
# event number 1735
# event number 1736
# event number 1737
# event number 1738
# event number 1739
# event number 1740
# event number 1741
# event number 1742
# event number 1743
# event number 1744
# event number 1745
# event number 1746
# event number 1747
# event number 1748
# event number 1749
# event number 1750
# event number 1751
# event number 1752
# event number 1753
# event number 1754
# event number 1755
# event number 1756
# event number 1757
# event number 1758
# event number 1759
# event number 1760
# event number 1761
# event number 1762
# event number 1763
# event number 1764
# event number 1765
# event number 1766
# event number 1767
# event number 1768
# event number 1769
# event number 1770
# event number 1771
# event number 1772
# event number 1773
# event number 1774
# event number 1775
# event number 1776
# event number 1777
# event number 1778
# event number 1779
# event number 1780
# event number 1781
# event number 1782
# event number 1783
# event number 1784
# event number 1785
# event number 1786
# event number 1787
# event number 1788
# event number 1789
# event number 1790
# event number 1791
# event number 1792
# event number 1793
# event number 1794
# event number 1795
# event number 1796
# event number 1797
# event number 1798
# event number 1799
# event number 1800
# event number 1801
# event number 1802
# event number 1803
# event number 1804
# event number 1805
# event number 1806
# event number 1807
# event number 1808
# event number 1809
# event number 1810
# event number 1811
# event number 1812
# event number 1813
# event number 1814
# event number 1815
# event number 1816
# event number 1817
# event number 1818
# event number 1819
# event number 1820
# event number 1821
# event number 1822
# event number 1823
# event number 1824
# event number 1825
# event number 1826
# event number 1827
# event number 1828
# event number 1829
# event number 1830
# event number 1831
# event number 1832
# event number 1833
# event number 1834
# event number 1835
# event number 1836
# event number 1837
# event number 1838
# event number 1839
# event number 1840
# event number 1841
# event number 1842
# event number 1843
# event number 1844
# event number 1845
# event number 1846
# event number 1847
# event number 1848
# event number 1849
# event number 1850
# event number 1851
# event number 1852
# event number 1853
# event number 1854
# event number 1855
# event number 1856
# event number 1857
# event number 1858
# event number 1859
# event number 1860
# event number 1861
# event number 1862
# event number 1863
# event number 1864
# event number 1865
# event number 1866
# event number 1867
# event number 1868
# event number 1869
# event number 1870
# event number 1871
# event number 1872
# event number 1873
# event number 1874
# event number 1875
# event number 1876
# event number 1877
# event number 1878
# event number 1879
# event number 1880
# event number 1881
# event number 1882
# event number 1883
# event number 1884
# event number 1885
# event number 1886
# event number 1887
# event number 1888
# event number 1889
# event number 1890
# event number 1891
# event number 1892
# event number 1893
# event number 1894
# event number 1895
# event number 1896
# event number 1897
# event number 1898
# event number 1899
# event number 1900
# event number 1901
# event number 1902
# event number 1903
# event number 1904
# event number 1905
# event number 1906
# event number 1907
# event number 1908
# event number 1909
# event number 1910
# event number 1911
# event number 1912
# event number 1913
# event number 1914
# event number 1915
# event number 1916
# event number 1917
# event number 1918
# event number 1919
# event number 1920
# event number 1921
# event number 1922
# event number 1923
# event number 1924
# event number 1925
# event number 1926
# event number 1927
# event number 1928
# event number 1929
# event number 1930
# event number 1931
# event number 1932
# event number 1933
# event number 1934
# event number 1935
# event number 1936
# event number 1937
# event number 1938
# event number 1939
# event number 1940
# event number 1941
# event number 1942
# event number 1943
# event number 1944
# event number 1945
# event number 1946
# event number 1947
# event number 1948
# event number 1949
# event number 1950
# event number 1951
# event number 1952
# event number 1953
# event number 1954
# event number 1955
# event number 1956
# event number 1957
# event number 1958
# event number 1959
# event number 1960
# event number 1961
# event number 1962
# event number 1963
# event number 1964
# event number 1965
# event number 1966
# event number 1967
# event number 1968
# event number 1969
# event number 1970
# event number 1971
# event number 1972
# event number 1973
# event number 1974
# event number 1975
# event number 1976
# event number 1977
# event number 1978
# event number 1979
# event number 1980
# event number 1981
# event number 1982
# event number 1983
# event number 1984
# event number 1985
# event number 1986
# event number 1987
# event number 1988
# event number 1989
# event number 1990
# event number 1991
# event number 1992
# event number 1993
# event number 1994
# event number 1995
# event number 1996
# event number 1997
# event number 1998
# event number 1999
# event number 2000
# event number 2001
# event number 2002
# event number 2003
# event number 2004
# event number 2005
# event number 2006
# event number 2007
# event number 2008
# event number 2009
# event number 2010
# event number 2011
# event number 2012
# event number 2013
# event number 2014
# event number 2015
# event number 2016
# event number 2017
# event number 2018
# event number 2019
# event number 2020
# event number 2021
# event number 2022
# event number 2023
# event number 2024
# event number 2025
# event number 2026
# event number 2027
# event number 2028
# event number 2029
# event number 2030
# event number 2031
# event number 2032
# event number 2033
# event number 2034
# event number 2035
# event number 2036
# event number 2037
# event number 2038
# event number 2039
# event number 2040
# event number 2041
# event number 2042
# event number 2043
# event number 2044
# event number 2045
# event number 2046
# event number 2047
# event number 2048
# event number 2049
# event number 2050
# event number 2051
# event number 2052
# event number 2053
# event number 2054
# event number 2055
# event number 2056
# event number 2057
# event number 2058
# event number 2059
# event number 2060
# event number 2061
# event number 2062
# event number 2063
# event number 2064
# event number 2065
# event number 2066
# event number 2067
# event number 2068
# event number 2069
# event number 2070
# event number 2071
# event number 2072
# event number 2073
# event number 2074
# event number 2075
# event number 2076
# event number 2077
# event number 2078
# event number 2079
# event number 2080
# event number 2081
# event number 2082
# event number 2083
# event number 2084
# event number 2085
# event number 2086
# event number 2087
# event number 2088
# event number 2089
# event number 2090
# event number 2091
# event number 2092
# event number 2093
# event number 2094
# event number 2095
# event number 2096
# event number 2097
# event number 2098
# event number 2099
# event number 2100
# event number 2101
# event number 2102
# event number 2103
# event number 2104
# event number 2105
# event number 2106
# event number 2107
# event number 2108
# event number 2109
# event number 2110
# event number 2111
# event number 2112
# event number 2113
# event number 2114
# event number 2115
# event number 2116
# event number 2117
# event number 2118
# event number 2119
# event number 2120
# event number 2121
# event number 2122
# event number 2123
# event number 2124
# event number 2125
# event number 2126
# event number 2127
# event number 2128
# event number 2129
# event number 2130
# event number 2131
# event number 2132
# event number 2133
# event number 2134
# event number 2135
# event number 2136
# event number 2137
# event number 2138
# event number 2139
# event number 2140
# event number 2141
# event number 2142
# event number 2143
# event number 2144
# event number 2145
# event number 2146
# event number 2147
# event number 2148
# event number 2149
# event number 2150
# event number 2151
# event number 2152
# event number 2153
# event number 2154
# event number 2155
# event number 2156
# event number 2157
# event number 2158
# event number 2159
# event number 2160
# event number 2161
# event number 2162
# event number 2163
# event number 2164
# event number 2165
# event number 2166
# event number 2167
# event number 2168
# event number 2169
# event number 2170
# event number 2171
# event number 2172
# event number 2173
# event number 2174
# event number 2175
# event number 2176
# event number 2177
# event number 2178
# event number 2179
# event number 2180
# event number 2181
# event number 2182
# event number 2183
# event number 2184
# event number 2185
# event number 2186
# event number 2187
# event number 2188
# event number 2189
# event number 2190
# event number 2191
# event number 2192
# event number 2193
# event number 2194
# event number 2195
# event number 2196
# event number 2197
# event number 2198
# event number 2199
# event number 2200
# event number 2201
# event number 2202
# event number 2203
# event number 2204
# event number 2205
# event number 2206
# event number 2207
# event number 2208
# event number 2209
# event number 2210
# event number 2211
# event number 2212
# event number 2213
# event number 2214
# event number 2215
# event number 2216
# event number 2217
# event number 2218
# event number 2219
# event number 2220
# event number 2221
# event number 2222
# event number 2223
# event number 2224
# event number 2225
# event number 2226
# event number 2227
# event number 2228
# event number 2229
# event number 2230
# event number 2231
# event number 2232
# event number 2233
# event number 2234
# event number 2235
# event number 2236
# event number 2237
# event number 2238
# event number 2239
# event number 2240
# event number 2241
# event number 2242
# event number 2243
# event number 2244
# event number 2245
# event number 2246
# event number 2247
# event number 2248
# event number 2249
# event number 2250
# event number 2251
# event number 2252
# event number 2253
# event number 2254
# event number 2255
# event number 2256
# event number 2257
# event number 2258
# event number 2259
# event number 2260
# event number 2261
# event number 2262
# event number 2263
# event number 2264
# event number 2265
# event number 2266
# event number 2267
# event number 2268
# event number 2269
# event number 2270
# event number 2271
# event number 2272
# event number 2273
# event number 2274
# event number 2275
# event number 2276
# event number 2277
# event number 2278
# event number 2279
# event number 2280
# event number 2281
# event number 2282
# event number 2283
# event number 2284
# event number 2285
# event number 2286
# event number 2287
# event number 2288
# event number 2289
# event number 2290
# event number 2291
# event number 2292
# event number 2293
# event number 2294
# event number 2295
# event number 2296
# event number 2297
# event number 2298
# event number 2299
# event number 2300
# event number 2301
# event number 2302
# event number 2303
# event number 2304
# event number 2305
# event number 2306
# event number 2307
# event number 2308
# event number 2309
# event number 2310
# event number 2311
# event number 2312
# event number 2313
# event number 2314
# event number 2315
# event number 2316
# event number 2317
# event number 2318
# event number 2319
# event number 2320
# event number 2321
# event number 2322
# event number 2323
# event number 2324
# event number 2325
# event number 2326
# event number 2327
# event number 2328
# event number 2329
# event number 2330
# event number 2331
# event number 2332
# event number 2333
# event number 2334
# event number 2335
# event number 2336
# event number 2337
# event number 2338
# event number 2339
# event number 2340
# event number 2341
# event number 2342
# event number 2343
# event number 2344
# event number 2345
# event number 2346
# event number 2347
# event number 2348
# event number 2349
# event number 2350
# event number 2351
# event number 2352
# event number 2353
# event number 2354
# event number 2355
# event number 2356
# event number 2357
# event number 2358
# event number 2359
# event number 2360
# event number 2361
# event number 2362
# event number 2363
# event number 2364
# event number 2365
# event number 2366
# event number 2367
# event number 2368
# event number 2369
# event number 2370
# event number 2371
# event number 2372
# event number 2373
# event number 2374
# event number 2375
# event number 2376
# event number 2377
# event number 2378
# event number 2379
# event number 2380
# event number 2381
# event number 2382
# event number 2383
# event number 2384
# event number 2385
# event number 2386
# event number 2387
# event number 2388
# event number 2389
# event number 2390
# event number 2391
# event number 2392
# event number 2393
# event number 2394
# event number 2395
# event number 2396
# event number 2397
# event number 2398
# event number 2399
# event number 2400
# event number 2401
# event number 2402
# event number 2403
# event number 2404
# event number 2405
# event number 2406
# event number 2407
# event number 2408
# event number 2409
# event number 2410
# event number 2411
# event number 2412
# event number 2413
# event number 2414
# event number 2415
# event number 2416
# event number 2417
# event number 2418
# event number 2419
# event number 2420
# event number 2421
# event number 2422
# event number 2423
# event number 2424
# event number 2425
# event number 2426
# event number 2427
# event number 2428
# event number 2429
# event number 2430
# event number 2431
# event number 2432
# event number 2433
# event number 2434
# event number 2435
# event number 2436
# event number 2437
# event number 2438
# event number 2439
# event number 2440
# event number 2441
# event number 2442
# event number 2443
# event number 2444
# event number 2445
# event number 2446
# event number 2447
# event number 2448
# event number 2449
# event number 2450
# event number 2451
# event number 2452
# event number 2453
# event number 2454
# event number 2455
# event number 2456
# event number 2457
# event number 2458
# event number 2459
# event number 2460
# event number 2461
# event number 2462
# event number 2463
# event number 2464
# event number 2465
# event number 2466
# event number 2467
# event number 2468
# event number 2469
# event number 2470
# event number 2471
# event number 2472
# event number 2473
# event number 2474
# event number 2475
# event number 2476
# event number 2477
# event number 2478
# event number 2479
# event number 2480
# event number 2481
# event number 2482
# event number 2483
# event number 2484
# event number 2485
# event number 2486
# event number 2487
# event number 2488
# event number 2489
# event number 2490
# event number 2491
# event number 2492
# event number 2493
# event number 2494
# event number 2495
# event number 2496
# event number 2497
# event number 2498
# event number 2499
# event number 2500
# event number 2501
# event number 2502
# event number 2503
# event number 2504
# event number 2505
# event number 2506
# event number 2507
# event number 2508
# event number 2509
# event number 2510
# event number 2511
# event number 2512
# event number 2513
# event number 2514
# event number 2515
# event number 2516
# event number 2517
# event number 2518
# event number 2519
# event number 2520
# event number 2521
# event number 2522
# event number 2523
# event number 2524
# event number 2525
# event number 2526
# event number 2527
# event number 2528
# event number 2529
# event number 2530
# event number 2531
# event number 2532
# event number 2533
# event number 2534
# event number 2535
# event number 2536
# event number 2537
# event number 2538
# event number 2539
# event number 2540
# event number 2541
# event number 2542
# event number 2543
# event number 2544
# event number 2545
# event number 2546
# event number 2547
# event number 2548
# event number 2549
# event number 2550
# event number 2551
# event number 2552
# event number 2553
# event number 2554
# event number 2555
# event number 2556
# event number 2557
# event number 2558
# event number 2559
# event number 2560
# event number 2561
# event number 2562
# event number 2563
# event number 2564
# event number 2565
# event number 2566
# event number 2567
# event number 2568
# event number 2569
# event number 2570
# event number 2571
# event number 2572
# event number 2573
# event number 2574
# event number 2575
# event number 2576
# event number 2577
# event number 2578
# event number 2579
# event number 2580
# event number 2581
# event number 2582
# event number 2583
# event number 2584
# event number 2585
# event number 2586
# event number 2587
# event number 2588
# event number 2589
# event number 2590
# event number 2591
# event number 2592
# event number 2593
# event number 2594
# event number 2595
# event number 2596
# event number 2597
# event number 2598
# event number 2599
# event number 2600
# event number 2601
# event number 2602
# event number 2603
# event number 2604
# event number 2605
# event number 2606
# event number 2607
# event number 2608
# event number 2609
# event number 2610
# event number 2611
# event number 2612
# event number 2613
# event number 2614
# event number 2615
# event number 2616
# event number 2617
# event number 2618
# event number 2619
# event number 2620
# event number 2621
# event number 2622
# event number 2623
# event number 2624
# event number 2625
# event number 2626
# event number 2627
# event number 2628
# event number 2629
# event number 2630
# event number 2631
# event number 2632
# event number 2633
# event number 2634
# event number 2635
# event number 2636
# event number 2637
# event number 2638
# event number 2639
# event number 2640
# event number 2641
# event number 2642
# event number 2643
# event number 2644
# event number 2645
# event number 2646
# event number 2647
# event number 2648
# event number 2649
# event number 2650
# event number 2651
# event number 2652
# event number 2653
# event number 2654
# event number 2655
# event number 2656
# event number 2657
# event number 2658
# event number 2659
# event number 2660
# event number 2661
# event number 2662
# event number 2663
# event number 2664
# event number 2665
# event number 2666
# event number 2667
# event number 2668
# event number 2669
# event number 2670
# event number 2671
# event number 2672
# event number 2673
# event number 2674
# event number 2675
# event number 2676
# event number 2677
# event number 2678
# event number 2679
# event number 2680
# event number 2681
# event number 2682
# event number 2683
# event number 2684
# event number 2685
# event number 2686
# event number 2687
# event number 2688
# event number 2689
# event number 2690
# event number 2691
# event number 2692
# event number 2693
# event number 2694
# event number 2695
# event number 2696
# event number 2697
# event number 2698
# event number 2699
# event number 2700
# event number 2701
# event number 2702
# event number 2703
# event number 2704
# event number 2705
# event number 2706
# event number 2707
# event number 2708
# event number 2709
# event number 2710
# event number 2711
# event number 2712
# event number 2713
# event number 2714
# event number 2715
# event number 2716
# event number 2717
# event number 2718
# event number 2719
# event number 2720
# event number 2721
# event number 2722
# event number 2723
# event number 2724
# event number 2725
# event number 2726
# event number 2727
# ...
# event number 4078
# event number 4079
# event number 4080
# event number 4081
# event number 4082
# event number 4083
# event number 4084
# event number 4085
# event number 4086
# event number 4087
# event number 4088
# event number 4089
# event number 4090
# event number 4091
# event number 4092
# event number 4093
# event number 4094
# event number 4095
# event number 4096
# event number 4097
# event number 4098
# event number 4099
# event number 4100
# event number 4101
# event number 4102
# event number 4103
# event number 4104
# event number 4105
# event number 4106
# event number 4107
# event number 4108
# event number 4109
# event number 4110
# event number 4111
# event number 4112
# event number 4113
# event number 4114
# event number 4115
# event number 4116
# event number 4117
# event number 4118
# event number 4119
# event number 4120
# event number 4121
# event number 4122
# event number 4123
# event number 4124
# event number 4125
# event number 4126
# event number 4127
# event number 4128
# event number 4129
# event number 4130
# event number 4131
# event number 4132
# event number 4133
# event number 4134
# event number 4135
# event number 4136
# event number 4137
# event number 4138
# event number 4139
# event number 4140
# event number 4141
# event number 4142
# event number 4143
# event number 4144
# event number 4145
# event number 4146
# event number 4147
# event number 4148
# event number 4149
# event number 4150
# event number 4151
# event number 4152
# event number 4153
# event number 4154
# event number 4155
# event number 4156
# event number 4157
# event number 4158
# event number 4159
# event number 4160
# event number 4161
# event number 4162
# event number 4163
# event number 4164
# event number 4165
# event number 4166
# event number 4167
# event number 4168
# event number 4169
# event number 4170
# event number 4171
# event number 4172
# event number 4173
# event number 4174
# event number 4175
# event number 4176
# event number 4177
# event number 4178
# event number 4179
# event number 4180
# event number 4181
# event number 4182
# event number 4183
# event number 4184
# event number 4185
# event number 4186
# event number 4187
# event number 4188
# event number 4189
# event number 4190
# event number 4191
# event number 4192
# event number 4193
# event number 4194
# event number 4195
# event number 4196
# event number 4197
# event number 4198
# event number 4199
# event number 4200
# event number 4201
# event number 4202
# event number 4203
# event number 4204
# event number 4205
# event number 4206
# event number 4207
# event number 4208
# event number 4209
# event number 4210
# event number 4211
# event number 4212
# event number 4213
# event number 4214
# event number 4215
# event number 4216
# event number 4217
# event number 4218
# event number 4219
# event number 4220
# event number 4221
# event number 4222
# event number 4223
# event number 4224
# event number 4225
# event number 4226
# event number 4227
# event number 4228
# event number 4229
# event number 4230
# event number 4231
# event number 4232
# event number 4233
# event number 4234
# event number 4235
# event number 4236
# event number 4237
# event number 4238
# event number 4239
# event number 4240
# event number 4241
# event number 4242
# event number 4243
# event number 4244
# event number 4245
# event number 4246
# event number 4247
# event number 4248
# event number 4249
# event number 4250
# event number 4251
# event number 4252
# event number 4253
# event number 4254
# event number 4255
# event number 4256
# event number 4257
# event number 4258
# event number 4259
# event number 4260
# event number 4261
# event number 4262
# event number 4263
# event number 4264
# event number 4265
# event number 4266
# event number 4267
# event number 4268
# event number 4269
# event number 4270
# event number 4271
# event number 4272
# event number 4273
# event number 4274
# event number 4275
# event number 4276
# event number 4277
# event number 4278
# event number 4279
# event number 4280
# event number 4281
# event number 4282
# event number 4283
# event number 4284
# event number 4285
# event number 4286
# event number 4287
# event number 4288
# event number 4289
# event number 4290
# event number 4291
# event number 4292
# event number 4293
# event number 4294
# event number 4295
# event number 4296
# event number 4297
# event number 4298
# event number 4299
# event number 4300
# event number 4301
# event number 4302
# event number 4303
# event number 4304
# event number 4305
# event number 4306
# event number 4307
# event number 4308
# event number 4309
# event number 4310
# event number 4311
# event number 4312
# event number 4313
# event number 4314
# event number 4315
# event number 4316
# event number 4317
# event number 4318
# event number 4319
# event number 4320
# event number 4321
# event number 4322
# event number 4323
# event number 4324
# event number 4325
# event number 4326
# event number 4327
# event number 4328
# event number 4329
# event number 4330
# event number 4331
# event number 4332
# event number 4333
# event number 4334
# event number 4335
# event number 4336
# event number 4337
# event number 4338
# event number 4339
# event number 4340
# event number 4341
# event number 4342
# event number 4343
# event number 4344
# event number 4345
# event number 4346
# event number 4347
# event number 4348
# event number 4349
# event number 4350
# event number 4351
# event number 4352
# event number 4353
# event number 4354
# event number 4355
# event number 4356
# event number 4357
# event number 4358
# event number 4359
# event number 4360
# event number 4361
# event number 4362
# event number 4363
# event number 4364
# event number 4365
# event number 4366
# event number 4367
# event number 4368
# event number 4369
# event number 4370
# event number 4371
# event number 4372
# event number 4373
# event number 4374
# event number 4375
# event number 4376
# event number 4377
# event number 4378
# event number 4379
# event number 4380
# event number 4381
# event number 4382
# event number 4383
# event number 4384
# event number 4385
# event number 4386
# event number 4387
# event number 4388
# event number 4389
# event number 4390
# event number 4391
# event number 4392
# event number 4393
# event number 4394
# event number 4395
# event number 4396
# event number 4397
# event number 4398
# event number 4399
# event number 4400
# event number 4401
# event number 4402
# event number 4403
# event number 4404
# event number 4405
# event number 4406
# event number 4407
# event number 4408
# event number 4409
# event number 4410
# event number 4411
# event number 4412
# event number 4413
# event number 4414
# event number 4415
# event number 4416
# event number 4417
# event number 4418
# event number 4419
# event number 4420
# event number 4421
# event number 4422
# event number 4423
# event number 4424
# event number 4425
# event number 4426
# event number 4427
# event number 4428
# event number 4429
# event number 4430
# event number 4431
# event number 4432
# event number 4433
# event number 4434
# event number 4435
# event number 4436
# event number 4437
# event number 4438
# event number 4439
# event number 4440
# event number 4441
# event number 4442
# event number 4443
# event number 4444
# event number 4445
# event number 4446
# event number 4447
# event number 4448
# event number 4449
# event number 4450
# event number 4451
# event number 4452
# event number 4453
# event number 4454
# event number 4455
# event number 4456
# event number 4457
# event number 4458
# event number 4459
# event number 4460
# event number 4461
# event number 4462
# event number 4463
# event number 4464
# event number 4465
# event number 4466
# event number 4467
# event number 4468
# event number 4469
# event number 4470
# event number 4471
# event number 4472
# event number 4473
# event number 4474
# event number 4475
# event number 4476
# event number 4477
# event number 4478
# event number 4479
# event number 4480
# event number 4481
# event number 4482
# event number 4483
# event number 4484
# event number 4485
# event number 4486
# event number 4487
# event number 4488
# event number 4489
# event number 4490
# event number 4491
# event number 4492
# event number 4493
# event number 4494
# event number 4495
# event number 4496
# event number 4497
# event number 4498
# event number 4499
# event number 0
# event number 1
# event number 2
# event number 3
# event number 4
# event number 5
# event number 6
# event number 7
# event number 8
# event number 9
# event number 10
# event number 11
# event number 12
# event number 13
# event number 14
# event number 15
# event number 16
# event number 17
# event number 18
# event number 19
# event number 20
# event number 21
# event number 22
# event number 23
# event number 24
# event number 25
# event number 26
# event number 27
# event number 28
# event number 29
# event number 30
# event number 31
# event number 32
# event number 33
# event number 34
# event number 35
# event number 36
# event number 37
# event number 38
# event number 39
# event number 40
# event number 41
# event number 42
# event number 43
# event number 44
# event number 45
# event number 46
# event number 47
# event number 48
# event number 49
# event number 50
# event number 51
# event number 52
# event number 53
# event number 54
# event number 55
# event number 56
# event number 57
# event number 58
# event number 59
# event number 60
# event number 61
# event number 62
# event number 63
# event number 64
# event number 65
# event number 66
# event number 67
# event number 68
# event number 69
# event number 70
# event number 71
# event number 72
# event number 73
# event number 74
# event number 75
# event number 76
# event number 77
# event number 78
# event number 79
# event number 80
# event number 81
# event number 82
# event number 83
# event number 84
# event number 85
# event number 86
# event number 87
# event number 88
# event number 89
# event number 90
# event number 91
# event number 92
# event number 93
# event number 94
# event number 95
# event number 96
# event number 97
# event number 98
# event number 99
# event number 100
# event number 101
# event number 102
# event number 103
# event number 104
# event number 105
# event number 106
# event number 107
# event number 108
# event number 109
# event number 110
# event number 111
# event number 112
# event number 113
# event number 114
# event number 115
# event number 116
# event number 117
# event number 118
# event number 119
# event number 120
# event number 121
# event number 122
# event number 123
# event number 124
# event number 125
# event number 126
# event number 127
# event number 128
# event number 129
# event number 130
# event number 131
# event number 132
# event number 133
# event number 134
# event number 135
# event number 136
# event number 137
# event number 138
# event number 139
# event number 140
# event number 141
# event number 142
# event number 143
# event number 144
# event number 145
# event number 146
# event number 147
# event number 148
# event number 149
# event number 150
# event number 151
# event number 152
# event number 153
# event number 154
# event number 155
# event number 156
# event number 157
# event number 158
# event number 159
# event number 160
# event number 161
# event number 162
# event number 163
# event number 164
# event number 165
# event number 166
# event number 167
# event number 168
# event number 169
# event number 170
# event number 171
# event number 172
# event number 173
# event number 174
# event number 175
# event number 176
# event number 177
# event number 178
# event number 179
# event number 180
# event number 181
# event number 182
# event number 183
# event number 184
# event number 185
# event number 186
# event number 187
# event number 188
# event number 189
# event number 190
# event number 191
# event number 192
# event number 193
# event number 194
# event number 195
# event number 196
# event number 197
# event number 198
# event number 199
# event number 200
# event number 201
# event number 202
# event number 203
# event number 204
# event number 205
# event number 206
# event number 207
# event number 208
# event number 209
# event number 210
# event number 211
# event number 212
# event number 213
# event number 214
# event number 215
# event number 216
# event number 217
# event number 218
# event number 219
# event number 220
# event number 221
# event number 222
# event number 223
# event number 224
# event number 225
# event number 226
# event number 227
# event number 228
# event number 229
# event number 230
# event number 231
# event number 232
# event number 233
# event number 234
# event number 235
# event number 236
# event number 237
# event number 238
# event number 239
# event number 240
# event number 241
# event number 242
# event number 243
# event number 244
# event number 245
# event number 246
# event number 247
# event number 248
# event number 249
# event number 250
# event number 251
# event number 252
# event number 253
# event number 254
# event number 255
# event number 256
# event number 257
# event number 258
# event number 259
# event number 260
# event number 261
# event number 262
# event number 263
# event number 264
# event number 265
# event number 266
# event number 267
# event number 268
# event number 269
# event number 270
# event number 271
# event number 272
# event number 273
# event number 274
# event number 275
# event number 276
# event number 277
# event number 278
# event number 279
# event number 280
# event number 281
# event number 282
# event number 283
# event number 284
# event number 285
# event number 286
# event number 287
# event number 288
# event number 289
# event number 290
# event number 291
# event number 292
# event number 293
# event number 294
# event number 295
# event number 296
# event number 297
# event number 298
# event number 299
# event number 300
# event number 301
# event number 302
# event number 303
# event number 304
# event number 305
# event number 306
# event number 307
# event number 308
# event number 309
# event number 310
# event number 311
# event number 312
# event number 313
# event number 314
# event number 315
# event number 316
# event number 317
# event number 318
# event number 319
# event number 320
# event number 321
# event number 322
# event number 323
# event number 324
# event number 325
# event number 326
# event number 327
# event number 328
# event number 329
# event number 330
# event number 331
# event number 332
# event number 333
# event number 334
# event number 335
# event number 336
# event number 337
# event number 338
# event number 339
# event number 340
# event number 341
# event number 342
# event number 343
# event number 344
# event number 345
# event number 346
# event number 347
# event number 348
# event number 349
# event number 350
# event number 351
# event number 352
# event number 353
# event number 354
# event number 355
# event number 356
# event number 357
# event number 358
# event number 359
# event number 360
# event number 361
# event number 362
# event number 363
# event number 364
# event number 365
# event number 366
# event number 367
# event number 368
# event number 369
# event number 370
# event number 371
# event number 372
# event number 373
# event number 374
# event number 375
# event number 376
# event number 377
# event number 378
# event number 379
# event number 380
# event number 381
# event number 382
# event number 383
# event number 384
# event number 385
# event number 386
# event number 387
# event number 388
# event number 389
# event number 390
# event number 391
# event number 392
# event number 393
# event number 394
# event number 395
# event number 396
# event number 397
# event number 398
# event number 399
# event number 400
# event number 401
# event number 402
# event number 403
# event number 404
# event number 405
# event number 406
# event number 407
# event number 408
# event number 409
# event number 410
# event number 411
# event number 412
# event number 413
# event number 414
# event number 415
# event number 416
# event number 417
# event number 418
# event number 419
# event number 420
# event number 421
# event number 422
# event number 423
# event number 424
# event number 425
# event number 426
# event number 427
# event number 428
# event number 429
# event number 430
# event number 431
# event number 432
# event number 433
# event number 434
# event number 435
# event number 436
# event number 437
# event number 438
# event number 439
# event number 440
# event number 441
# event number 442
# event number 443
# event number 444
# event number 445
# event number 446
# event number 447
# event number 448
# event number 449
# event number 450
# event number 451
# event number 452
# event number 453
# event number 454
# event number 455
# event number 456
# event number 457
# event number 458
# event number 459
# event number 460
# event number 461
# event number 462
# event number 463
# event number 464
# event number 465
# event number 466
# event number 467
# event number 468
# event number 469
# event number 470
# event number 471
# event number 472
# event number 473
# event number 474
# event number 475
# event number 476
# event number 477
# event number 478
# event number 479
# event number 480
# event number 481
# event number 482
# event number 483
# event number 484
# event number 485
# event number 486
# event number 487
# event number 488
# event number 489
# event number 490
# event number 491
# event number 492
# event number 493
# event number 494
# event number 495
# event number 496
# event number 497
# event number 498
# event number 499

# %%
device
# Out:
# device(type='cuda', index=0)

# %%
encoder = Encoder()
net = Net(encoder)

train_losses, val_losses = finetune_model(encoder, net, train_loader, val_loader)
# Out:
# new 2
# [1,  1000], loss: 0.592
# [1,  2000], loss: 0.403
# [1,  3000], loss: 0.354
# [1,  4000], loss: 0.329
# [1,  5000], loss: 0.295
# [1,  6000], loss: 0.278
# [1,  7000], loss: 0.260
# [1,  8000], loss: 0.250
# [1,  9000], loss: 0.243
# [Epoch  1] Epoch Loss: 0.33004 | Val Loss: 0.22877, Val Accuracy: 0.90620
# [2,  1000], loss: 0.235
# [2,  2000], loss: 0.230
# [2,  3000], loss: 0.225
# [2,  4000], loss: 0.220
# [2,  5000], loss: 0.216
# [2,  6000], loss: 0.212
# [2,  7000], loss: 0.205
# [2,  8000], loss: 0.203
# [2,  9000], loss: 0.197
# [Epoch  2] Epoch Loss: 0.21515 | Val Loss: 0.18702, Val Accuracy: 0.92650
# New Best Loss: 0.18702
# [3,  1000], loss: 0.189
# [3,  2000], loss: 0.186
# [3,  3000], loss: 0.183
# [3,  4000], loss: 0.182
# [3,  5000], loss: 0.178
# [3,  6000], loss: 0.177
# [3,  7000], loss: 0.175
# [3,  8000], loss: 0.172
# [3,  9000], loss: 0.170
# [Epoch  3] Epoch Loss: 0.17867 | Val Loss: 0.17398, Val Accuracy: 0.93315
# New Best Loss: 0.17398
# [4,  1000], loss: 0.168
# [4,  2000], loss: 0.164
# [4,  3000], loss: 0.165
# [4,  4000], loss: 0.163
# [4,  5000], loss: 0.162
# [4,  6000], loss: 0.161
# [4,  7000], loss: 0.161
# [4,  8000], loss: 0.160
# [4,  9000], loss: 0.158
# [Epoch  4] Epoch Loss: 0.16211 | Val Loss: 0.16700, Val Accuracy: 0.93580
# New Best Loss: 0.16700
# [5,  1000], loss: 0.154
# [5,  2000], loss: 0.154
# [5,  3000], loss: 0.152
# [5,  4000], loss: 0.154
# [5,  5000], loss: 0.151
# [5,  6000], loss: 0.150
# [5,  7000], loss: 0.147
# [5,  8000], loss: 0.148
# [5,  9000], loss: 0.147
# [Epoch  5] Epoch Loss: 0.15051 | Val Loss: 0.16050, Val Accuracy: 0.93914
# New Best Loss: 0.16050
# [6,  1000], loss: 0.144
# [6,  2000], loss: 0.144
# [6,  3000], loss: 0.143
# [6,  4000], loss: 0.143
# [6,  5000], loss: 0.143
# [6,  6000], loss: 0.141
# [6,  7000], loss: 0.141
# [6,  8000], loss: 0.141
# [6,  9000], loss: 0.140
# [Epoch  6] Epoch Loss: 0.14220 | Val Loss: 0.15868, Val Accuracy: 0.94038
# New Best Loss: 0.15868
# [7,  1000], loss: 0.139
# [7,  2000], loss: 0.138
# [7,  3000], loss: 0.139
# [7,  4000], loss: 0.137
# [7,  5000], loss: 0.138
# [7,  6000], loss: 0.135
# [7,  7000], loss: 0.135
# [7,  8000], loss: 0.135
# [7,  9000], loss: 0.135
# [Epoch  7] Epoch Loss: 0.13674 | Val Loss: 0.15096, Val Accuracy: 0.94203
# New Best Loss: 0.15096
# [8,  1000], loss: 0.133
# [8,  2000], loss: 0.133
# [8,  3000], loss: 0.132
# [8,  4000], loss: 0.134
# [8,  5000], loss: 0.133
# [8,  6000], loss: 0.132
# [8,  7000], loss: 0.132
# [8,  8000], loss: 0.131
# [8,  9000], loss: 0.131
# [Epoch  8] Epoch Loss: 0.13229 | Val Loss: 0.15093, Val Accuracy: 0.94255
# New Best Loss: 0.15093
# [9,  1000], loss: 0.130
# [9,  2000], loss: 0.130
# [9,  3000], loss: 0.129
# [9,  4000], loss: 0.130
# [9,  5000], loss: 0.129
# [9,  6000], loss: 0.130
# [9,  7000], loss: 0.129
# [9,  8000], loss: 0.129
# [9,  9000], loss: 0.128
# [Epoch  9] Epoch Loss: 0.12921 | Val Loss: 0.15270, Val Accuracy: 0.94335
# [10,  1000], loss: 0.127
# [10,  2000], loss: 0.129
# [10,  3000], loss: 0.128
# [10,  4000], loss: 0.127
# [10,  5000], loss: 0.126
# [10,  6000], loss: 0.127
# [10,  7000], loss: 0.127
# [10,  8000], loss: 0.125
# [10,  9000], loss: 0.126
# [Epoch 10] Epoch Loss: 0.12680 | Val Loss: 0.15247, Val Accuracy: 0.94184
# [11,  1000], loss: 0.125
# [11,  2000], loss: 0.124
# [11,  3000], loss: 0.125
# [11,  4000], loss: 0.125
# [11,  5000], loss: 0.124
# [11,  6000], loss: 0.125
# [11,  7000], loss: 0.124
# [11,  8000], loss: 0.123
# [11,  9000], loss: 0.125
# [Epoch 11] Epoch Loss: 0.12436 | Val Loss: 0.14658, Val Accuracy: 0.94497
# New Best Loss: 0.14658
# [12,  1000], loss: 0.121
# [12,  2000], loss: 0.122
# [12,  3000], loss: 0.123
# [12,  4000], loss: 0.123
# [12,  5000], loss: 0.124
# [12,  6000], loss: 0.123
# [12,  7000], loss: 0.121
# [12,  8000], loss: 0.122
# [12,  9000], loss: 0.122
# [Epoch 12] Epoch Loss: 0.12230 | Val Loss: 0.14618, Val Accuracy: 0.94590
# New Best Loss: 0.14618
# [13,  1000], loss: 0.121
# [13,  2000], loss: 0.122
# [13,  3000], loss: 0.120
# [13,  4000], loss: 0.121
# [13,  5000], loss: 0.121
# [13,  6000], loss: 0.121
# [13,  7000], loss: 0.120
# [13,  8000], loss: 0.120
# [13,  9000], loss: 0.120
# [Epoch 13] Epoch Loss: 0.12052 | Val Loss: 0.14262, Val Accuracy: 0.94695
# New Best Loss: 0.14262
# [14,  1000], loss: 0.119
# [14,  2000], loss: 0.119
# [14,  3000], loss: 0.119
# [14,  4000], loss: 0.120
# [14,  5000], loss: 0.119
# [14,  6000], loss: 0.118
# [14,  7000], loss: 0.119
# [14,  8000], loss: 0.118
# [14,  9000], loss: 0.118
# [Epoch 14] Epoch Loss: 0.11892 | Val Loss: 0.14880, Val Accuracy: 0.94155
# [15,  1000], loss: 0.117
# [15,  2000], loss: 0.117
# [15,  3000], loss: 0.117
# [15,  4000], loss: 0.118
# [15,  5000], loss: 0.118
# [15,  6000], loss: 0.118
# [15,  7000], loss: 0.116
# [15,  8000], loss: 0.117
# [15,  9000], loss: 0.118
# [Epoch 15] Epoch Loss: 0.11740 | Val Loss: 0.15740, Val Accuracy: 0.94406
# [16,  1000], loss: 0.116
# [16,  2000], loss: 0.116
# [16,  3000], loss: 0.115
# [16,  4000], loss: 0.117
# [16,  5000], loss: 0.117
# [16,  6000], loss: 0.116
# [16,  7000], loss: 0.117
# [16,  8000], loss: 0.115
# [16,  9000], loss: 0.116
# [Epoch 16] Epoch Loss: 0.11613 | Val Loss: 0.13800, Val Accuracy: 0.94880
# New Best Loss: 0.13800
# [17,  1000], loss: 0.115
# [17,  2000], loss: 0.115
# [17,  3000], loss: 0.114
# [17,  4000], loss: 0.114
# [17,  5000], loss: 0.115
# [17,  6000], loss: 0.114
# [17,  7000], loss: 0.115
# [17,  8000], loss: 0.116
# [17,  9000], loss: 0.117
# [Epoch 17] Epoch Loss: 0.11505 | Val Loss: 0.14473, Val Accuracy: 0.94497
# [18,  1000], loss: 0.113
# [18,  2000], loss: 0.114
# [18,  3000], loss: 0.114
# [18,  4000], loss: 0.113
# [18,  5000], loss: 0.113
# [18,  6000], loss: 0.113
# [18,  7000], loss: 0.114
# [18,  8000], loss: 0.114
# [18,  9000], loss: 0.115
# [Epoch 18] Epoch Loss: 0.11379 | Val Loss: 0.13807, Val Accuracy: 0.94741
# [19,  1000], loss: 0.113
# [19,  2000], loss: 0.113
# [19,  3000], loss: 0.115
# [19,  4000], loss: 0.113
# [19,  5000], loss: 0.112
# [19,  6000], loss: 0.114
# [19,  7000], loss: 0.112
# [19,  8000], loss: 0.113
# [19,  9000], loss: 0.113
# [Epoch 19] Epoch Loss: 0.11307 | Val Loss: 0.14388, Val Accuracy: 0.94824
# [20,  1000], loss: 0.112
# [20,  2000], loss: 0.112
# [20,  3000], loss: 0.112
# [20,  4000], loss: 0.111
# [20,  5000], loss: 0.113
# [20,  6000], loss: 0.113
# [20,  7000], loss: 0.112
# [20,  8000], loss: 0.112
# [20,  9000], loss: 0.113
# [Epoch 20] Epoch Loss: 0.11228 | Val Loss: 0.14181, Val Accuracy: 0.94815
# [21,  1000], loss: 0.111
# [21,  2000], loss: 0.111
# [21,  3000], loss: 0.111
# [21,  4000], loss: 0.111
# [21,  5000], loss: 0.112
# [21,  6000], loss: 0.111
# [21,  7000], loss: 0.114
# [21,  8000], loss: 0.113
# [21,  9000], loss: 0.112
# [Epoch 21] Epoch Loss: 0.11188 | Val Loss: 0.13984, Val Accuracy: 0.94804
# [22,  1000], loss: 0.112
# [22,  2000], loss: 0.112
# [22,  3000], loss: 0.110
# [22,  4000], loss: 0.112
# [22,  5000], loss: 0.112
# [22,  6000], loss: 0.111
# [22,  7000], loss: 0.111
# [22,  8000], loss: 0.112
# [22,  9000], loss: 0.112
# [Epoch 22] Epoch Loss: 0.11159 | Val Loss: 0.13584, Val Accuracy: 0.94886
# New Best Loss: 0.13584
# [23,  1000], loss: 0.111
# [23,  2000], loss: 0.110
# [23,  3000], loss: 0.112
# [23,  4000], loss: 0.109
# [23,  5000], loss: 0.110
# [23,  6000], loss: 0.111
# [23,  7000], loss: 0.112
# [23,  8000], loss: 0.111
# [23,  9000], loss: 0.109
# [Epoch 23] Epoch Loss: 0.11061 | Val Loss: 0.14491, Val Accuracy: 0.94793
# [24,  1000], loss: 0.111
# [24,  2000], loss: 0.109
# [24,  3000], loss: 0.110
# [24,  4000], loss: 0.111
# [24,  5000], loss: 0.111
# [24,  6000], loss: 0.110
# [24,  7000], loss: 0.110
# [24,  8000], loss: 0.111
# [24,  9000], loss: 0.110
# [Epoch 24] Epoch Loss: 0.11046 | Val Loss: 0.15615, Val Accuracy: 0.94321
# [25,  1000], loss: 0.108
# [25,  2000], loss: 0.111
# [25,  3000], loss: 0.112
# [25,  4000], loss: 0.110
# [25,  5000], loss: 0.110
# [25,  6000], loss: 0.111
# [25,  7000], loss: 0.111
# [25,  8000], loss: 0.111
# [25,  9000], loss: 0.111
# [Epoch 25] Epoch Loss: 0.11053 | Val Loss: 0.13957, Val Accuracy: 0.94777
# [26,  1000], loss: 0.109
# [26,  2000], loss: 0.109
# [26,  3000], loss: 0.110
# [26,  4000], loss: 0.108
# [26,  5000], loss: 0.110
# [26,  6000], loss: 0.111
# [26,  7000], loss: 0.110
# [26,  8000], loss: 0.110
# [26,  9000], loss: 0.109
# [Epoch 26] Epoch Loss: 0.10953 | Val Loss: 0.13966, Val Accuracy: 0.94788
# [27,  1000], loss: 0.109
# [27,  2000], loss: 0.108
# [27,  3000], loss: 0.110
# [27,  4000], loss: 0.109
# [27,  5000], loss: 0.110
# [27,  6000], loss: 0.110
# [27,  7000], loss: 0.109
# [27,  8000], loss: 0.110
# [27,  9000], loss: 0.108
# [Epoch 27] Epoch Loss: 0.10912 | Val Loss: 0.14019, Val Accuracy: 0.94922
# [28,  1000], loss: 0.108
# [28,  2000], loss: 0.109
# [28,  3000], loss: 0.109
# [28,  4000], loss: 0.109
# [28,  5000], loss: 0.109
# [28,  6000], loss: 0.109
# [28,  7000], loss: 0.108
# [28,  8000], loss: 0.108
# [28,  9000], loss: 0.109
# [Epoch 28] Epoch Loss: 0.10870 | Val Loss: 0.13829, Val Accuracy: 0.94842
# [29,  1000], loss: 0.107
# [29,  2000], loss: 0.109
# [29,  3000], loss: 0.108
# [29,  4000], loss: 0.109
# [29,  5000], loss: 0.109
# [29,  6000], loss: 0.109
# [29,  7000], loss: 0.108
# [29,  8000], loss: 0.108
# [29,  9000], loss: 0.109
# [Epoch 29] Epoch Loss: 0.10834 | Val Loss: 0.13414, Val Accuracy: 0.95076
# New Best Loss: 0.13414
# [30,  1000], loss: 0.108
# [30,  2000], loss: 0.108
# [30,  3000], loss: 0.108
# [30,  4000], loss: 0.108
# [30,  5000], loss: 0.108
# [30,  6000], loss: 0.107
# [30,  7000], loss: 0.109
# [30,  8000], loss: 0.108
# [30,  9000], loss: 0.110
# [Epoch 30] Epoch Loss: 0.10825 | Val Loss: 0.13725, Val Accuracy: 0.94836
# [31,  1000], loss: 0.108
# [31,  2000], loss: 0.108
# [31,  3000], loss: 0.109
# [31,  4000], loss: 0.109
# [31,  5000], loss: 0.107
# [31,  6000], loss: 0.109
# [31,  7000], loss: 0.108
# [31,  8000], loss: 0.107
# [31,  9000], loss: 0.108
# [Epoch 31] Epoch Loss: 0.10810 | Val Loss: 0.13671, Val Accuracy: 0.94855
# [32,  1000], loss: 0.107
# [32,  2000], loss: 0.106
# [32,  3000], loss: 0.108
# [32,  4000], loss: 0.108
# [32,  5000], loss: 0.108
# [32,  6000], loss: 0.108
# [32,  7000], loss: 0.107
# [32,  8000], loss: 0.108
# [32,  9000], loss: 0.108
# [Epoch 32] Epoch Loss: 0.10752 | Val Loss: 0.16959, Val Accuracy: 0.93370
# [33,  1000], loss: 0.106
# [33,  2000], loss: 0.107
# [33,  3000], loss: 0.107
# [33,  4000], loss: 0.108
# [33,  5000], loss: 0.107
# [33,  6000], loss: 0.108
# [33,  7000], loss: 0.109
# [33,  8000], loss: 0.107
# [33,  9000], loss: 0.107
# [Epoch 33] Epoch Loss: 0.10733 | Val Loss: 0.14017, Val Accuracy: 0.94845
# [34,  1000], loss: 0.107
# [34,  2000], loss: 0.107
# [34,  3000], loss: 0.107
# [34,  4000], loss: 0.108
# [34,  5000], loss: 0.107
# [34,  6000], loss: 0.108
# [34,  7000], loss: 0.107
# [34,  8000], loss: 0.108
# [34,  9000], loss: 0.108
# [Epoch 34] Epoch Loss: 0.10711 | Val Loss: 0.13621, Val Accuracy: 0.94853
# [35,  1000], loss: 0.105
# [35,  2000], loss: 0.107
# [35,  3000], loss: 0.106
# [35,  4000], loss: 0.107
# [35,  5000], loss: 0.107
# [35,  6000], loss: 0.106
# [35,  7000], loss: 0.108
# [35,  8000], loss: 0.106
# [35,  9000], loss: 0.108
# [Epoch 35] Epoch Loss: 0.10681 | Val Loss: 0.13563, Val Accuracy: 0.95074
# [36,  1000], loss: 0.106
# [36,  2000], loss: 0.106
# [36,  3000], loss: 0.107
# [36,  4000], loss: 0.107
# [36,  5000], loss: 0.108
# [36,  6000], loss: 0.107
# [36,  7000], loss: 0.108
# [36,  8000], loss: 0.106
# [36,  9000], loss: 0.106
# [Epoch 36] Epoch Loss: 0.10673 | Val Loss: 0.13423, Val Accuracy: 0.94961
# [37,  1000], loss: 0.105
# [37,  2000], loss: 0.106
# [37,  3000], loss: 0.106
# [37,  4000], loss: 0.106
# [37,  5000], loss: 0.106
# [37,  6000], loss: 0.108
# [37,  7000], loss: 0.106
# [37,  8000], loss: 0.106
# [37,  9000], loss: 0.107
# [Epoch 37] Epoch Loss: 0.10625 | Val Loss: 0.13872, Val Accuracy: 0.94754
# [38,  1000], loss: 0.105
# [38,  2000], loss: 0.104
# [38,  3000], loss: 0.107
# [38,  4000], loss: 0.106
# [38,  5000], loss: 0.107
# [38,  6000], loss: 0.107
# [38,  7000], loss: 0.107
# [38,  8000], loss: 0.106
# [38,  9000], loss: 0.107
# [Epoch 38] Epoch Loss: 0.10611 | Val Loss: 0.14456, Val Accuracy: 0.94825
# [39,  1000], loss: 0.106
# [39,  2000], loss: 0.105
# [39,  3000], loss: 0.105
# [39,  4000], loss: 0.106
# [39,  5000], loss: 0.106
# [39,  6000], loss: 0.106
# [39,  7000], loss: 0.105
# [39,  8000], loss: 0.107
# [39,  9000], loss: 0.107
# [Epoch 39] Epoch Loss: 0.10586 | Val Loss: 0.13279, Val Accuracy: 0.95126
# New Best Loss: 0.13279
# [40,  1000], loss: 0.105
# [40,  2000], loss: 0.106
# [40,  3000], loss: 0.105
# [40,  4000], loss: 0.106
# [40,  5000], loss: 0.106
# [40,  6000], loss: 0.106
# [40,  7000], loss: 0.105
# [40,  8000], loss: 0.107
# [40,  9000], loss: 0.107
# [Epoch 40] Epoch Loss: 0.10596 | Val Loss: 0.14556, Val Accuracy: 0.94420
# [41,  1000], loss: 0.105
# [41,  2000], loss: 0.106
# [41,  3000], loss: 0.106
# [41,  4000], loss: 0.106
# [41,  5000], loss: 0.107
# [41,  6000], loss: 0.108
# [41,  7000], loss: 0.106
# [41,  8000], loss: 0.106
# [41,  9000], loss: 0.106
# [Epoch 41] Epoch Loss: 0.10624 | Val Loss: 0.14489, Val Accuracy: 0.94733
# [42,  1000], loss: 0.107
# [42,  2000], loss: 0.105
# [42,  3000], loss: 0.105
# [42,  4000], loss: 0.106
# [42,  5000], loss: 0.106
# [42,  6000], loss: 0.105
# [42,  7000], loss: 0.108
# [42,  8000], loss: 0.105
# [42,  9000], loss: 0.106
# [Epoch 42] Epoch Loss: 0.10584 | Val Loss: 0.14222, Val Accuracy: 0.94532
# [43,  1000], loss: 0.105
# [43,  2000], loss: 0.106
# [43,  3000], loss: 0.107
# [43,  4000], loss: 0.105
# [43,  5000], loss: 0.106
# [43,  6000], loss: 0.105
# [43,  7000], loss: 0.105
# [43,  8000], loss: 0.105
# [43,  9000], loss: 0.106
# [Epoch 43] Epoch Loss: 0.10563 | Val Loss: 0.13771, Val Accuracy: 0.94839
# [44,  1000], loss: 0.104
# [44,  2000], loss: 0.105
# [44,  3000], loss: 0.106
# [44,  4000], loss: 0.106
# [44,  5000], loss: 0.105
# [44,  6000], loss: 0.105
# [44,  7000], loss: 0.106
# [44,  8000], loss: 0.106
# [44,  9000], loss: 0.106
# [Epoch 44] Epoch Loss: 0.10556 | Val Loss: 0.13749, Val Accuracy: 0.94719
# [45,  1000], loss: 0.106
# [45,  2000], loss: 0.105
# [45,  3000], loss: 0.104
# [45,  4000], loss: 0.107
# [45,  5000], loss: 0.106
# [45,  6000], loss: 0.107
# [45,  7000], loss: 0.106
# [45,  8000], loss: 0.106
# [45,  9000], loss: 0.105
# [Epoch 45] Epoch Loss: 0.10577 | Val Loss: 0.13209, Val Accuracy: 0.95010
# New Best Loss: 0.13209
# [46,  1000], loss: 0.105
# [46,  2000], loss: 0.105
# [46,  3000], loss: 0.106
# [46,  4000], loss: 0.105
# [46,  5000], loss: 0.106
# [46,  6000], loss: 0.105
# [46,  7000], loss: 0.106
# [46,  8000], loss: 0.104
# [46,  9000], loss: 0.106
# [Epoch 46] Epoch Loss: 0.10549 | Val Loss: 0.13596, Val Accuracy: 0.94819
# [47,  1000], loss: 0.105
# [47,  2000], loss: 0.106
# [47,  3000], loss: 0.104
# [47,  4000], loss: 0.105
# [47,  5000], loss: 0.106
# [47,  6000], loss: 0.105
# [47,  7000], loss: 0.107
# [47,  8000], loss: 0.105
# [47,  9000], loss: 0.106
# [Epoch 47] Epoch Loss: 0.10544 | Val Loss: 0.13582, Val Accuracy: 0.94932
# [48,  1000], loss: 0.105
# [48,  2000], loss: 0.106
# [48,  3000], loss: 0.105
# [48,  4000], loss: 0.106
# [48,  5000], loss: 0.105
# [48,  6000], loss: 0.105
# [48,  7000], loss: 0.105
# [48,  8000], loss: 0.106
# [48,  9000], loss: 0.106
# [Epoch 48] Epoch Loss: 0.10530 | Val Loss: 0.13229, Val Accuracy: 0.95113
# [49,  1000], loss: 0.104
# [49,  2000], loss: 0.104
# [49,  3000], loss: 0.104
# [49,  4000], loss: 0.105
# [49,  5000], loss: 0.105
# [49,  6000], loss: 0.106
# [49,  7000], loss: 0.105
# [49,  8000], loss: 0.105
# [49,  9000], loss: 0.107
# [Epoch 49] Epoch Loss: 0.10505 | Val Loss: 0.14087, Val Accuracy: 0.94911
# [50,  1000], loss: 0.105
# [50,  2000], loss: 0.103
# [50,  3000], loss: 0.104
# [50,  4000], loss: 0.105
# [50,  5000], loss: 0.105
# [50,  6000], loss: 0.106
# [50,  7000], loss: 0.105
# [50,  8000], loss: 0.105
# [50,  9000], loss: 0.105
# [Epoch 50] Epoch Loss: 0.10479 | Val Loss: 0.13521, Val Accuracy: 0.95023
# [51,  1000], loss: 0.104
# [51,  2000], loss: 0.104
# [51,  3000], loss: 0.105
# [51,  4000], loss: 0.104
# [51,  5000], loss: 0.105
# [51,  6000], loss: 0.105
# [51,  7000], loss: 0.105
# [51,  8000], loss: 0.105
# [51,  9000], loss: 0.104
# [Epoch 51] Epoch Loss: 0.10468 | Val Loss: 0.13915, Val Accuracy: 0.94902
# [52,  1000], loss: 0.103
# [52,  2000], loss: 0.106
# [52,  3000], loss: 0.104
# [52,  4000], loss: 0.105
# [52,  5000], loss: 0.106
# [52,  6000], loss: 0.104
# [52,  7000], loss: 0.106
# [52,  8000], loss: 0.105
# [52,  9000], loss: 0.104
# [Epoch 52] Epoch Loss: 0.10470 | Val Loss: 0.14042, Val Accuracy: 0.94839
# [53,  1000], loss: 0.103
# [53,  2000], loss: 0.104
# [53,  3000], loss: 0.104
# [53,  4000], loss: 0.105
# [53,  5000], loss: 0.105
# [53,  6000], loss: 0.104
# [53,  7000], loss: 0.105
# [53,  8000], loss: 0.106
# [53,  9000], loss: 0.105
# [Epoch 53] Epoch Loss: 0.10433 | Val Loss: 0.13635, Val Accuracy: 0.94858
# [54,  1000], loss: 0.104
# [54,  2000], loss: 0.104
# [54,  3000], loss: 0.104
# [54,  4000], loss: 0.104
# [54,  5000], loss: 0.104
# [54,  6000], loss: 0.105
# [54,  7000], loss: 0.105
# [54,  8000], loss: 0.104
# [54,  9000], loss: 0.104
# [Epoch 54] Epoch Loss: 0.10434 | Val Loss: 0.13903, Val Accuracy: 0.94770
# [55,  1000], loss: 0.103
# [55,  2000], loss: 0.103
# [55,  3000], loss: 0.104
# [55,  4000], loss: 0.105
# [55,  5000], loss: 0.105
# [55,  6000], loss: 0.103
# [55,  7000], loss: 0.105
# [55,  8000], loss: 0.104
# [55,  9000], loss: 0.104
# [Epoch 55] Epoch Loss: 0.10417 | Val Loss: 0.14343, Val Accuracy: 0.94933
# [56,  1000], loss: 0.104
# [56,  2000], loss: 0.104
# [56,  3000], loss: 0.103
# [56,  4000], loss: 0.104
# [56,  5000], loss: 0.104
# [56,  6000], loss: 0.105
# [56,  7000], loss: 0.105
# [56,  8000], loss: 0.103
# [56,  9000], loss: 0.105
# [Epoch 56] Epoch Loss: 0.10413 | Val Loss: 0.13519, Val Accuracy: 0.94978
# [57,  1000], loss: 0.103
# [57,  2000], loss: 0.102
# [57,  3000], loss: 0.105
# [57,  4000], loss: 0.104
# [57,  5000], loss: 0.103
# [57,  6000], loss: 0.105
# [57,  7000], loss: 0.105
# [57,  8000], loss: 0.104
# [57,  9000], loss: 0.105
# [Epoch 57] Epoch Loss: 0.10404 | Val Loss: 0.13703, Val Accuracy: 0.94833
# [58,  1000], loss: 0.103
# [58,  2000], loss: 0.105
# [58,  3000], loss: 0.103
# [58,  4000], loss: 0.104
# [58,  5000], loss: 0.102
# [58,  6000], loss: 0.105
# [58,  7000], loss: 0.105
# [58,  8000], loss: 0.104
# [58,  9000], loss: 0.105
# [Epoch 58] Epoch Loss: 0.10404 | Val Loss: 0.13721, Val Accuracy: 0.94837
# [59,  1000], loss: 0.103
# [59,  2000], loss: 0.103
# [59,  3000], loss: 0.103
# [59,  4000], loss: 0.104
# [59,  5000], loss: 0.104
# [59,  6000], loss: 0.105
# [59,  7000], loss: 0.105
# [59,  8000], loss: 0.105
# [59,  9000], loss: 0.103
# [Epoch 59] Epoch Loss: 0.10394 | Val Loss: 0.14077, Val Accuracy: 0.94999
# [60,  1000], loss: 0.104
# [60,  2000], loss: 0.103
# [60,  3000], loss: 0.104
# [60,  4000], loss: 0.104
# [60,  5000], loss: 0.104
# [60,  6000], loss: 0.105
# [60,  7000], loss: 0.104
# [60,  8000], loss: 0.106
# [60,  9000], loss: 0.105
# [Epoch 60] Epoch Loss: 0.10429 | Val Loss: 0.13589, Val Accuracy: 0.95066
# [61,  1000], loss: 0.103
# [61,  2000], loss: 0.103
# [61,  3000], loss: 0.103
# [61,  4000], loss: 0.104
# [61,  5000], loss: 0.103
# [61,  6000], loss: 0.105
# [61,  7000], loss: 0.105
# [61,  8000], loss: 0.104
# [61,  9000], loss: 0.104
# [Epoch 61] Epoch Loss: 0.10385 | Val Loss: 0.13811, Val Accuracy: 0.94931
# [62,  1000], loss: 0.102
# [62,  2000], loss: 0.104
# [62,  3000], loss: 0.103
# [62,  4000], loss: 0.103
# [62,  5000], loss: 0.104
# [62,  6000], loss: 0.105
# [62,  7000], loss: 0.104
# [62,  8000], loss: 0.104
# [62,  9000], loss: 0.104
# [Epoch 62] Epoch Loss: 0.10364 | Val Loss: 0.13635, Val Accuracy: 0.94932
# [63,  1000], loss: 0.102
# [63,  2000], loss: 0.103
# [63,  3000], loss: 0.105
# [63,  4000], loss: 0.104
# [63,  5000], loss: 0.103
# [63,  6000], loss: 0.105
# [63,  7000], loss: 0.103
# [63,  8000], loss: 0.104
# [63,  9000], loss: 0.105
# [Epoch 63] Epoch Loss: 0.10364 | Val Loss: 0.13768, Val Accuracy: 0.94802
# [64,  1000], loss: 0.102
# [64,  2000], loss: 0.104
# [64,  3000], loss: 0.103
# [64,  4000], loss: 0.103
# [64,  5000], loss: 0.104
# [64,  6000], loss: 0.104
# [64,  7000], loss: 0.103
# [64,  8000], loss: 0.104
# [64,  9000], loss: 0.104
# [Epoch 64] Epoch Loss: 0.10339 | Val Loss: 0.14256, Val Accuracy: 0.94838
# [65,  1000], loss: 0.102
# [65,  2000], loss: 0.103
# [65,  3000], loss: 0.102
# [65,  4000], loss: 0.103
# [65,  5000], loss: 0.104
# [65,  6000], loss: 0.104
# [65,  7000], loss: 0.103
# [65,  8000], loss: 0.104
# [65,  9000], loss: 0.105
# [Epoch 65] Epoch Loss: 0.10329 | Val Loss: 0.14113, Val Accuracy: 0.94700
# [66,  1000], loss: 0.103
# [66,  2000], loss: 0.102
# [66,  3000], loss: 0.103
# [66,  4000], loss: 0.103
# [66,  5000], loss: 0.104
# [66,  6000], loss: 0.105
# [66,  7000], loss: 0.104
# [66,  8000], loss: 0.105
# [66,  9000], loss: 0.103
# [Epoch 66] Epoch Loss: 0.10351 | Val Loss: 0.13807, Val Accuracy: 0.94863
# [67,  1000], loss: 0.103
# [67,  2000], loss: 0.104
# [67,  3000], loss: 0.104
# [67,  4000], loss: 0.104
# [67,  5000], loss: 0.104
# [67,  6000], loss: 0.104
# [67,  7000], loss: 0.103
# [67,  8000], loss: 0.105
# [67,  9000], loss: 0.103
# [Epoch 67] Epoch Loss: 0.10377 | Val Loss: 0.13841, Val Accuracy: 0.94812
# [68,  1000], loss: 0.101
# [68,  2000], loss: 0.103
# [68,  3000], loss: 0.103
# [68,  4000], loss: 0.103
# [68,  5000], loss: 0.104
# [68,  6000], loss: 0.104
# [68,  7000], loss: 0.104
# [68,  8000], loss: 0.105
# [68,  9000], loss: 0.103
# [Epoch 68] Epoch Loss: 0.10339 | Val Loss: 0.14799, Val Accuracy: 0.94761
# [69,  1000], loss: 0.102
# [69,  2000], loss: 0.103
# [69,  3000], loss: 0.104
# [69,  4000], loss: 0.103
# [69,  5000], loss: 0.103
# [69,  6000], loss: 0.104
# [69,  7000], loss: 0.105
# [69,  8000], loss: 0.103
# [69,  9000], loss: 0.104
# [Epoch 69] Epoch Loss: 0.10357 | Val Loss: 0.13527, Val Accuracy: 0.95016
# [70,  1000], loss: 0.102
# [70,  2000], loss: 0.103
# [70,  3000], loss: 0.104
# [70,  4000], loss: 0.102
# [70,  5000], loss: 0.104
# [70,  6000], loss: 0.105
# [70,  7000], loss: 0.104
# [70,  8000], loss: 0.104
# [70,  9000], loss: 0.103
# [Epoch 70] Epoch Loss: 0.10334 | Val Loss: 0.13900, Val Accuracy: 0.94725
# [71,  1000], loss: 0.103
# [71,  2000], loss: 0.104
# [71,  3000], loss: 0.103
# [71,  4000], loss: 0.103
# [71,  5000], loss: 0.102
# [71,  6000], loss: 0.105
# [71,  7000], loss: 0.104
# [71,  8000], loss: 0.103
# [71,  9000], loss: 0.104
# [Epoch 71] Epoch Loss: 0.10334 | Val Loss: 0.14723, Val Accuracy: 0.94723
# [72,  1000], loss: 0.102
# [72,  2000], loss: 0.103
# [72,  3000], loss: 0.104
# [72,  4000], loss: 0.103
# [72,  5000], loss: 0.104
# [72,  6000], loss: 0.103
# [72,  7000], loss: 0.104
# [72,  8000], loss: 0.103
# [72,  9000], loss: 0.103
# [Epoch 72] Epoch Loss: 0.10319 | Val Loss: 0.13473, Val Accuracy: 0.94942
# [73,  1000], loss: 0.102
# [73,  2000], loss: 0.103
# [73,  3000], loss: 0.103
# [73,  4000], loss: 0.102
# [73,  5000], loss: 0.104
# [73,  6000], loss: 0.104
# [73,  7000], loss: 0.104
# [73,  8000], loss: 0.104
# [73,  9000], loss: 0.102
# [Epoch 73] Epoch Loss: 0.10299 | Val Loss: 0.13766, Val Accuracy: 0.94952
# [74,  1000], loss: 0.103
# [74,  2000], loss: 0.103
# [74,  3000], loss: 0.103
# [74,  4000], loss: 0.102
# [74,  5000], loss: 0.102
# [74,  6000], loss: 0.104
# [74,  7000], loss: 0.103
# [74,  8000], loss: 0.104
# [74,  9000], loss: 0.104
# [Epoch 74] Epoch Loss: 0.10314 | Val Loss: 0.13487, Val Accuracy: 0.95124
# [75,  1000], loss: 0.102
# [75,  2000], loss: 0.104
# [75,  3000], loss: 0.102
# [75,  4000], loss: 0.103
# [75,  5000], loss: 0.106
# [75,  6000], loss: 0.104
# [75,  7000], loss: 0.104
# [75,  8000], loss: 0.104
# [75,  9000], loss: 0.104
# [Epoch 75] Epoch Loss: 0.10369 | Val Loss: 0.13582, Val Accuracy: 0.94910
# [76,  1000], loss: 0.101
# [76,  2000], loss: 0.103
# [76,  3000], loss: 0.104
# [76,  4000], loss: 0.102
# [76,  5000], loss: 0.103
# [76,  6000], loss: 0.104
# [76,  7000], loss: 0.103
# [76,  8000], loss: 0.102
# [76,  9000], loss: 0.104
# [Epoch 76] Epoch Loss: 0.10293 | Val Loss: 0.13869, Val Accuracy: 0.95002
# [77,  1000], loss: 0.101
# [77,  2000], loss: 0.103
# [77,  3000], loss: 0.102
# [77,  4000], loss: 0.104
# [77,  5000], loss: 0.101
# [77,  6000], loss: 0.102
# [77,  7000], loss: 0.104
# [77,  8000], loss: 0.104
# [77,  9000], loss: 0.104
# [Epoch 77] Epoch Loss: 0.10276 | Val Loss: 0.14278, Val Accuracy: 0.94525
# [78,  1000], loss: 0.102
# [78,  2000], loss: 0.101
# [78,  3000], loss: 0.102
# [78,  4000], loss: 0.103
# [78,  5000], loss: 0.103
# [78,  6000], loss: 0.103
# [78,  7000], loss: 0.103
# [78,  8000], loss: 0.103
# [78,  9000], loss: 0.104
# [Epoch 78] Epoch Loss: 0.10267 | Val Loss: 0.13818, Val Accuracy: 0.94841
# [79,  1000], loss: 0.103
# [79,  2000], loss: 0.102
# [79,  3000], loss: 0.103
# [79,  4000], loss: 0.103
# [79,  5000], loss: 0.103
# [79,  6000], loss: 0.104
# [79,  7000], loss: 0.104
# [79,  8000], loss: 0.103
# [79,  9000], loss: 0.102
# [Epoch 79] Epoch Loss: 0.10294 | Val Loss: 0.14054, Val Accuracy: 0.94638
# [80,  1000], loss: 0.101
# [80,  2000], loss: 0.102
# [80,  3000], loss: 0.104
# [80,  4000], loss: 0.102
# [80,  5000], loss: 0.102
# [80,  6000], loss: 0.104
# [80,  7000], loss: 0.103
# [80,  8000], loss: 0.103
# [80,  9000], loss: 0.103
# [Epoch 80] Epoch Loss: 0.10269 | Val Loss: 0.13642, Val Accuracy: 0.94919
# [81,  1000], loss: 0.102
# [81,  2000], loss: 0.102
# [81,  3000], loss: 0.103
# [81,  4000], loss: 0.103
# [81,  5000], loss: 0.102
# [81,  6000], loss: 0.104
# [81,  7000], loss: 0.102
# [81,  8000], loss: 0.103
# [81,  9000], loss: 0.103
# [Epoch 81] Epoch Loss: 0.10265 | Val Loss: 0.13787, Val Accuracy: 0.94940
# [82,  1000], loss: 0.101
# [82,  2000], loss: 0.101
# [82,  3000], loss: 0.103
# [82,  4000], loss: 0.102
# [82,  5000], loss: 0.103
# [82,  6000], loss: 0.103
# [82,  7000], loss: 0.104
# [82,  8000], loss: 0.104
# [82,  9000], loss: 0.103
# [Epoch 82] Epoch Loss: 0.10271 | Val Loss: 0.14073, Val Accuracy: 0.94906
# [83,  1000], loss: 0.100
# [83,  2000], loss: 0.103
# [83,  3000], loss: 0.102
# [83,  4000], loss: 0.103
# [83,  5000], loss: 0.105
# [83,  6000], loss: 0.103
# [83,  7000], loss: 0.102
# [83,  8000], loss: 0.103
# [83,  9000], loss: 0.102
# [Epoch 83] Epoch Loss: 0.10266 | Val Loss: 0.14272, Val Accuracy: 0.94585
# [84,  1000], loss: 0.102
# [84,  2000], loss: 0.103
# [84,  3000], loss: 0.102
# [84,  4000], loss: 0.103
# [84,  5000], loss: 0.102
# [84,  6000], loss: 0.103
# [84,  7000], loss: 0.103
# [84,  8000], loss: 0.104
# [84,  9000], loss: 0.102
# [Epoch 84] Epoch Loss: 0.10262 | Val Loss: 0.13398, Val Accuracy: 0.95121
# [85,  1000], loss: 0.101
# [85,  2000], loss: 0.102
# [85,  3000], loss: 0.102
# [85,  4000], loss: 0.102
# [85,  5000], loss: 0.102
# [85,  6000], loss: 0.103
# [85,  7000], loss: 0.103
# [85,  8000], loss: 0.103
# [85,  9000], loss: 0.103
# [Epoch 85] Epoch Loss: 0.10241 | Val Loss: 0.14495, Val Accuracy: 0.94899
# [86,  1000], loss: 0.102
# [86,  2000], loss: 0.102
# [86,  3000], loss: 0.100
# [86,  4000], loss: 0.102
# [86,  5000], loss: 0.102
# [86,  6000], loss: 0.104
# [86,  7000], loss: 0.105
# [86,  8000], loss: 0.103
# [86,  9000], loss: 0.103
# [Epoch 86] Epoch Loss: 0.10240 | Val Loss: 0.14704, Val Accuracy: 0.94851
# [87,  1000], loss: 0.102
# [87,  2000], loss: 0.102
# [87,  3000], loss: 0.103
# [87,  4000], loss: 0.102
# [87,  5000], loss: 0.103
# [87,  6000], loss: 0.102
# [87,  7000], loss: 0.103
# [87,  8000], loss: 0.102
# [87,  9000], loss: 0.103
# [Epoch 87] Epoch Loss: 0.10233 | Val Loss: 0.13835, Val Accuracy: 0.95011
# [88,  1000], loss: 0.101
# [88,  2000], loss: 0.101
# [88,  3000], loss: 0.102
# [88,  4000], loss: 0.103
# [88,  5000], loss: 0.103
# [88,  6000], loss: 0.102
# [88,  7000], loss: 0.102
# [88,  8000], loss: 0.103
# [88,  9000], loss: 0.103
# [Epoch 88] Epoch Loss: 0.10237 | Val Loss: 0.14285, Val Accuracy: 0.94905
# [89,  1000], loss: 0.102
# [89,  2000], loss: 0.100
# [89,  3000], loss: 0.103
# [89,  4000], loss: 0.101
# [89,  5000], loss: 0.102
# [89,  6000], loss: 0.103
# [89,  7000], loss: 0.103
# [89,  8000], loss: 0.101
# [89,  9000], loss: 0.104
# [Epoch 89] Epoch Loss: 0.10231 | Val Loss: 0.13741, Val Accuracy: 0.94987
# [90,  1000], loss: 0.102
# [90,  2000], loss: 0.102
# [90,  3000], loss: 0.102
# [90,  4000], loss: 0.103
# [90,  5000], loss: 0.103
# [90,  6000], loss: 0.102
# [90,  7000], loss: 0.101
# [90,  8000], loss: 0.103
# [90,  9000], loss: 0.102
# [Epoch 90] Epoch Loss: 0.10226 | Val Loss: 0.14339, Val Accuracy: 0.94500
# [91,  1000], loss: 0.101
# [91,  2000], loss: 0.101
# [91,  3000], loss: 0.102
# [91,  4000], loss: 0.103
# [91,  5000], loss: 0.103
# [91,  6000], loss: 0.103
# [91,  7000], loss: 0.101
# [91,  8000], loss: 0.103
# [91,  9000], loss: 0.104
# [Epoch 91] Epoch Loss: 0.10228 | Val Loss: 0.14004, Val Accuracy: 0.94780
# [92,  1000], loss: 0.101
# [92,  2000], loss: 0.102
# [92,  3000], loss: 0.103
# [92,  4000], loss: 0.102
# [92,  5000], loss: 0.104
# [92,  6000], loss: 0.102
# [92,  7000], loss: 0.101
# [92,  8000], loss: 0.104
# [92,  9000], loss: 0.104
# [Epoch 92] Epoch Loss: 0.10244 | Val Loss: 0.14826, Val Accuracy: 0.94458
# [93,  1000], loss: 0.102
# [93,  2000], loss: 0.101
# [93,  3000], loss: 0.103
# [93,  4000], loss: 0.104
# [93,  5000], loss: 0.105
# [93,  6000], loss: 0.104
# [93,  7000], loss: 0.104
# [93,  8000], loss: 0.103
# [93,  9000], loss: 0.103
# [Epoch 93] Epoch Loss: 0.10338 | Val Loss: 0.14829, Val Accuracy: 0.94814
# [94,  1000], loss: 0.103
# [94,  2000], loss: 0.103
# [94,  3000], loss: 0.102
# [94,  4000], loss: 0.103
# [94,  5000], loss: 0.103
# [94,  6000], loss: 0.103
# [94,  7000], loss: 0.103
# [94,  8000], loss: 0.103
# [94,  9000], loss: 0.103
# [Epoch 94] Epoch Loss: 0.10275 | Val Loss: 0.16235, Val Accuracy: 0.94316
# [95,  1000], loss: 0.103
# [95,  2000], loss: 0.103
# [95,  3000], loss: 0.102
# [95,  4000], loss: 0.103
# [95,  5000], loss: 0.103
# [95,  6000], loss: 0.103
# [95,  7000], loss: 0.103
# [95,  8000], loss: 0.102
# [95,  9000], loss: 0.103
# [Epoch 95] Epoch Loss: 0.10280 | Val Loss: 0.13620, Val Accuracy: 0.95032
# [96,  1000], loss: 0.101
# [96,  2000], loss: 0.101
# [96,  3000], loss: 0.104
# [96,  4000], loss: 0.104
# [96,  5000], loss: 0.102
# [96,  6000], loss: 0.103
# [96,  7000], loss: 0.104
# [96,  8000], loss: 0.101
# [96,  9000], loss: 0.103
# [Epoch 96] Epoch Loss: 0.10243 | Val Loss: 0.15366, Val Accuracy: 0.94419
# [97,  1000], loss: 0.101
# [97,  2000], loss: 0.102
# [97,  3000], loss: 0.104
# [97,  4000], loss: 0.102
# [97,  5000], loss: 0.102
# [97,  6000], loss: 0.103
